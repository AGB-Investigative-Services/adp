# %%
# DataFrame handlers
import pandas as pd
import os
import numpy as np

# json
import json

# Datetime Manager
from datetime import datetime as dt
from datetime import timedelta, time, date


# Reading CSV file
data = pd.read_csv('resources/data/HR Dash.csv', encoding='ISO-8859-1', low_memory=False)

# Adding count column for to automate groupby count function
data['count'] = 1

# Changing data types of date columns. Current format is read Timestamp
data['Position Start Date'] = pd.to_datetime(data['Position Start Date'])
data['Hire Date'] = pd.to_datetime(data['Hire Date'])
data['Rehire Date'] = pd.to_datetime(data['Rehire Date'])

# Adding Columns
data['Hire Status'] = ''
data.loc[((data['Rehire Date'] == data['Position Start Date']) | (data['Hire Date'] < data['Position Start Date'])), 'Hire Status' ] = 'Rehire'
data.loc[data['Hire Status'] == '', 'Hire Status'] = 'New Hire'

# Adding Years of Service column and calulating the number of years worked
year = timedelta(days=365.25)
data['Years of Service'] = (dt.today() - data['Hire Date']) / year
data
# Out:
#                 Payroll Name Business Unit Description Position Status  \
# 0             Aaron, Charity           Darryl's Region          Active
# 1               Abdi, Gibril                       NaN      Terminated
# 2       Abdi, Suleiman Gulan                       NaN      Terminated
# 3           Abdullah, Maizar           Darryl's Region      Terminated
# 4           Abdullah, Rammah           Darryl's Region      Terminated
# ...                      ...                       ...             ...
# 2554           Zarif, Alexis            Steve's Region          Active
# 2555  Zayas, Benjamin Joseph                       NaN      Terminated
# 2556            Zayas, Reina            Administration          Active
# 2557        Zayas, Timothy G                       NaN      Terminated
# 2558         Zeigler, Mary R                       NaN      Terminated
#
#          Job Title Description  Hire Date Hire Reason Description Rehire Date  \
# 0     Unarmed Security Officer 2020-07-20            New Position         NaT
# 1              Unarmed Officer 2018-04-27                     NaN         NaT
# 2              Unarmed Officer 2018-06-05                     NaN         NaT
# 3     Unarmed Security Officer 2019-02-20            New Position         NaT
# 4     Unarmed Security Officer 2019-02-20            New Position         NaT
# ...                        ...        ...                     ...         ...
# 2554  Unarmed Security Officer 2018-07-30                     NaN         NaT
# 2555             Armed Officer 2016-11-15                     NaN         NaT
# 2556    Business Administrator 2020-05-22            New Position         NaT
# 2557             Armed Officer 2016-11-18                     NaN         NaT
# 2558           Unarmed Officer 2017-03-20                     NaN         NaT
#
#      Termination Date Position Start Date Termination Reason Description  \
# 0                 NaN          2020-07-20                            NaN
# 1           7/10/2018          2018-04-27                       Personal
# 2           7/10/2018          2018-06-05          Import Created Action
# 3           4/12/2019          2019-02-20          Voluntary Resignation
# 4           4/12/2019          2019-02-20          Voluntary Resignation
# ...               ...                 ...                            ...
# 2554              NaN          2018-07-30                            NaN
# 2555         4/4/2018          2016-11-15          Import Created Action
# 2556              NaN          2020-05-22                            NaN
# 2557        7/13/2018          2016-11-18          Import Created Action
# 2558        7/12/2018          2017-03-20          Import Created Action
#
#      Voluntary/Involuntary Termination Flag Position ID  count Hire Status  \
# 0                                       NaN   MVX001936      1    New Hire
# 1                               Involuntary   MVX000918      1    New Hire
# 2                                       NaN   MVX001002      1    New Hire
# 3                                 Voluntary   MVX001493      1    New Hire
# 4                                 Voluntary   MVX001495      1    New Hire
# ...                                     ...         ...    ...         ...
# 2554                                    NaN   MVX001095      1    New Hire
# 2555                                    NaN   MVX000392      1    New Hire
# 2556                                    NaN   RJS004315      1    New Hire
# 2557                                    NaN   MVX000395      1    New Hire
# 2558                                    NaN   MVX000486      1    New Hire
#
#       Years of Service
# 0             0.321428
# 1             2.552777
# 2             2.446001
# 3             1.734159
# 4             1.734159
# ...                ...
# 2554          2.295419
# 2555          3.998362
# 2556          0.482962
# 2557          3.990148
# 2558          3.656131
#
# [2559 rows x 15 columns]
