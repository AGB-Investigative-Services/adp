# %%
# DataFrame handlers
import pandas as pd
import os
import numpy as np

# json
import json

# Datetime Manager
from datetime import datetime as dt
from datetime import timedelta, time, date


# Reading CSV file
data = pd.read_csv('resources/data/HR Dash.csv', encoding='ISO-8859-1', low_memory=False)

# Adding count column for to automate groupby count function
data['count'] = 1

# Changing data types of date columns. Current format is read Timestamp
data['Position Start Date'] = pd.to_datetime(data['Position Start Date'])
data['Hire Date'] = pd.to_datetime(data['Hire Date'])
data['Hire Year'] = data['Hire Date'].dt.year
data['Rehire Date'] = pd.to_datetime(data['Rehire Date'])
data['Rehire Year'] = data['Rehire Date'].dt.year
data['Termination Date'] = pd.to_datetime(data['Termination Date'])
data['Termination Year'] = data['Termination Date'].dt.year

# Adding Columns
data['Hire Status'] = ''
data.loc[((data['Rehire Date'] == data['Position Start Date']) | (data['Hire Date'] < data['Position Start Date'])), 'Hire Status' ] = 'Rehire'
data.loc[data['Hire Status'] == '', 'Hire Status'] = 'New Hire'

# (https://docs.python.org/3.2/library/datetime.html)
# Adding Years of Service column and calulating the number of years worked
year = timedelta(days=365.25)
data['Years of Service'] = (dt.today() - data['Hire Date']) / year
data

# Formatting date columns to strings for JS Plotly Charts
# data['Position Start Date'] = data['Position Start Date'].dt.strftime('%Y-%m-%d')
# data['Hire Date'] = data['Hire Date'].dt.strftime('%Y-%m-%d')
# data['Rehire Date'] = data['Rehire Date'].dt.strftime('%Y-%m-%d')
# data['Termination Date'] = data['Termination Date'].dt.strftime('%Y-%m-%d')

# Removing "NaT" values from columns
# data.loc[data['Rehire Date'] == 'NaT', 'Rehire Date'] = "0"
# data.loc[data['Termination Date'] == 'NaT', 'Termination Date'] = "0"

data.to_json('resources/data/custom_hire_data.json', orient="records")
data_json = data.to_json(orient="records")
parsed = json.loads(data_json)
print(json.dumps(parsed, indent=4))
# Out:
# [
#     {
#         "Payroll Name": "Aaron, Charity",
#         "Business Unit Description": "Darryl's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": 1595203200000,
#         "Hire Reason Description": "New Position",
#         "Rehire Date": null,
#         "Termination Date": null,
#         "Position Start Date": 1595203200000,
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX001936",
#         "count": 1,
#         "Hire Year": 2020,
#         "Rehire Year": null,
#         "Termination Year": null,
#         "Hire Status": "New Hire",
#         "Years of Service": 0.3386554795
#     },
#     {
#         "Payroll Name": "Abdi, Gibril",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": 1524787200000,
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": 1531180800000,
#         "Position Start Date": 1524787200000,
#         "Termination Reason Description": "Personal",
#         "Voluntary/Involuntary Termination Flag": "Involuntary",
#         "Position ID": "MVX000918",
#         "count": 1,
#         "Hire Year": 2018,
#         "Rehire Year": null,
#         "Termination Year": 2018.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.570003871
#     },
#     {
#         "Payroll Name": "Abdi, Suleiman Gulan",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": 1528156800000,
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": 1531180800000,
#         "Position Start Date": 1528156800000,
#         "Termination Reason Description": "Import Created Action",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX001002",
#         "count": 1,
#         "Hire Year": 2018,
#         "Rehire Year": null,
#         "Termination Year": 2018.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.4632276903
#     },
#     {
#         "Payroll Name": "Abdullah, Maizar",
#         "Business Unit Description": "Darryl's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": 1550620800000,
#         "Hire Reason Description": "New Position",
#         "Rehire Date": null,
#         "Termination Date": 1555027200000,
#         "Position Start Date": 1550620800000,
#         "Termination Reason Description": "Voluntary Resignation",
#         "Voluntary/Involuntary Termination Flag": "Voluntary",
#         "Position ID": "MVX001493",
#         "count": 1,
#         "Hire Year": 2019,
#         "Rehire Year": null,
#         "Termination Year": 2019.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 1.7513864857
#     },
#     {
#         "Payroll Name": "Abdullah, Rammah",
#         "Business Unit Description": "Darryl's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": 1550620800000,
#         "Hire Reason Description": "New Position",
#         "Rehire Date": null,
#         "Termination Date": 1555027200000,
#         "Position Start Date": 1550620800000,
#         "Termination Reason Description": "Voluntary Resignation",
#         "Voluntary/Involuntary Termination Flag": "Voluntary",
#         "Position ID": "MVX001495",
#         "count": 1,
#         "Hire Year": 2019,
#         "Rehire Year": null,
#         "Termination Year": 2019.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 1.7513864857
#     },
#     {
#         "Payroll Name": "Aboyade-Cole, Toyin",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": 1520812800000,
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": 1530576000000,
#         "Position Start Date": 1520812800000,
#         "Termination Reason Description": "Import Created Action",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000820",
#         "count": 1,
#         "Hire Year": 2018,
#         "Rehire Year": null,
#         "Termination Year": 2018.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.6959450072
#     },
#     {
#         "Payroll Name": "Abraham, Tiara",
#         "Business Unit Description": "Darryl's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Armed Security Officer",
#         "Hire Date": 1579824000000,
#         "Hire Reason Description": "New Position",
#         "Rehire Date": null,
#         "Termination Date": 1596067200000,
#         "Position Start Date": 1579824000000,
#         "Termination Reason Description": "Abandoned Job",
#         "Voluntary/Involuntary Termination Flag": "Involuntary",
#         "Position ID": "MVX004190",
#         "count": 1,
#         "Hire Year": 2020,
#         "Rehire Year": null,
#         "Termination Year": 2020.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 0.8259929196
#     },
#     {
#         "Payroll Name": "Abron, Kenisha",
#         "Business Unit Description": "Administration",
#         "Position Status": "Terminated",
#         "Job Title Description": "Dispatch Supervisor",
#         "Hire Date": 1516752000000,
#         "Hire Reason Description": "Existing Position",
#         "Rehire Date": 1547164800000,
#         "Termination Date": 1573171200000,
#         "Position Start Date": 1547164800000,
#         "Termination Reason Description": "Personal",
#         "Voluntary/Involuntary Termination Flag": "Voluntary",
#         "Position ID": "MVX000749",
#         "count": 1,
#         "Hire Year": 2018,
#         "Rehire Year": 2019.0,
#         "Termination Year": 2019.0,
#         "Hire Status": "Rehire",
#         "Years of Service": 2.8246239942
#     },
#     {
#         "Payroll Name": "Acevedo-Dixon, Elantra",
#         "Business Unit Description": "Steve's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Nicor Dispatcher",
#         "Hire Date": 1557705600000,
#         "Hire Reason Description": "Existing Position",
#         "Rehire Date": null,
#         "Termination Date": 1574985600000,
#         "Position Start Date": 1557705600000,
#         "Termination Reason Description": "Employee Quit after Client Rejection",
#         "Voluntary/Involuntary Termination Flag": "Voluntary",
#         "Position ID": "MVX001632",
#         "count": 1,
#         "Hire Year": 2019,
#         "Rehire Year": null,
#         "Termination Year": 2019.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 1.5268827211
#     },
#     {
#         "Payroll Name": "Acheampong, Clive",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": 1524787200000,
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": 1546214400000,
#         "Position Start Date": 1524787200000,
#         "Termination Reason Description": "PayCom Conversion",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000941",
#         "count": 1,
#         "Hire Year": 2018,
#         "Rehire Year": null,
#         "Termination Year": 2018.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.570003871
#     },
#     {
#         "Payroll Name": "Adams, Amber",
#         "Business Unit Description": "Steve's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": 1534118400000,
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": null,
#         "Position Start Date": 1534118400000,
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX001123",
#         "count": 1,
#         "Hire Year": 2018,
#         "Rehire Year": null,
#         "Termination Year": null,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.274315986
#     },
#     {
#         "Payroll Name": "Adams, Don E",
#         "Business Unit Description": "Steve's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Armed Security Officer",
#         "Hire Date": 1499990400000,
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": null,
#         "Position Start Date": 1499990400000,
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000612",
#         "count": 1,
#         "Hire Year": 2017,
#         "Rehire Year": null,
#         "Termination Year": null,
#         "Hire Status": "New Hire",
#         "Years of Service": 3.3557670469
#     },
#     {
#         "Payroll Name": "Adams, Fletcher L",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": 1526256000000,
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": 1531180800000,
#         "Position Start Date": 1526256000000,
#         "Termination Reason Description": "Import Created Action",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000985",
#         "count": 1,
#         "Hire Year": 2018,
#         "Rehire Year": null,
#         "Termination Year": 2018.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.5234604077
#     },
#     {
#         "Payroll Name": "Adams, Jene",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": 1531699200000,
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": 1546214400000,
#         "Position Start Date": 1531699200000,
#         "Termination Reason Description": "PayCom Conversion",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX001068",
#         "count": 1,
#         "Hire Year": 2018,
#         "Rehire Year": null,
#         "Termination Year": 2018.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.3509758081
#     },
#     {
#         "Payroll Name": "Adams, Kamrin",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": 1526256000000,
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": 1534291200000,
#         "Position Start Date": 1526256000000,
#         "Termination Reason Description": "Import Created Action",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000978",
#         "count": 1,
#         "Hire Year": 2018,
#         "Rehire Year": null,
#         "Termination Year": 2018.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.5234604077
#     },
#     {
#         "Payroll Name": "Adams, Lotoninia",
#         "Business Unit Description": "Steve's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": 1522022400000,
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": 1555718400000,
#         "Position Start Date": 1522022400000,
#         "Termination Reason Description": "Voluntary Resignation",
#         "Voluntary/Involuntary Termination Flag": "Voluntary",
#         "Position ID": "MVX000838",
#         "count": 1,
#         "Hire Year": 2018,
#         "Rehire Year": null,
#         "Termination Year": 2019.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.6576150962
#     },
#     {
#         "Payroll Name": "Adams, Tiniya",
#         "Business Unit Description": "Darryl's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": 1583712000000,
#         "Hire Reason Description": "New Position",
#         "Rehire Date": null,
#         "Termination Date": null,
#         "Position Start Date": 1583712000000,
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX004319",
#         "count": 1,
#         "Hire Year": 2020,
#         "Rehire Year": null,
#         "Termination Year": null,
#         "Hire Status": "New Hire",
#         "Years of Service": 0.7027896342
#     },
#     {
#         "Payroll Name": "Adams-Jones, Eboni",
#         "Business Unit Description": "Darryl's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Operations Coordinator",
#         "Hire Date": 1583107200000,
#         "Hire Reason Description": "New Position",
#         "Rehire Date": null,
#         "Termination Date": null,
#         "Position Start Date": 1583107200000,
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX004308",
#         "count": 1,
#         "Hire Year": 2020,
#         "Rehire Year": null,
#         "Termination Year": null,
#         "Hire Status": "New Hire",
#         "Years of Service": 0.7219545897
#     },
#     {
#         "Payroll Name": "Adan, Abdi Marshale",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": 1533772800000,
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": 1546214400000,
#         "Position Start Date": 1533772800000,
#         "Termination Reason Description": "PayCom Conversion",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX001117",
#         "count": 1,
#         "Hire Year": 2018,
#         "Rehire Year": null,
#         "Termination Year": 2018.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.2852673892
#     },
#     {
#         "Payroll Name": "Adan, Bishar Noor",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": 1528156800000,
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": 1546214400000,
#         "Position Start Date": 1528156800000,
#         "Termination Reason Description": "PayCom Conversion",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX001005",
#         "count": 1,
#         "Hire Year": 2018,
#         "Rehire Year": null,
#         "Termination Year": 2018.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.4632276903
#     },
#     {
#         "Payroll Name": "Adan, Yahya Noor",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": 1528156800000,
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": 1533772800000,
#         "Position Start Date": 1528156800000,
#         "Termination Reason Description": "Import Created Action",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX001004",
#         "count": 1,
#         "Hire Year": 2018,
#         "Rehire Year": null,
#         "Termination Year": 2018.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.4632276903
#     },
#     {
#         "Payroll Name": "Adomako, Prince",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": 1528156800000,
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": 1546214400000,
#         "Position Start Date": 1528156800000,
#         "Termination Reason Description": "PayCom Conversion",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX001009",
#         "count": 1,
#         "Hire Year": 2018,
#         "Rehire Year": null,
#         "Termination Year": 2018.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.4632276903
#     },
#     {
#         "Payroll Name": "Adshade, Thomas Michael",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": 1485907200000,
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": 1546214400000,
#         "Position Start Date": 1485907200000,
#         "Termination Reason Description": "PayCom Conversion",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000436",
#         "count": 1,
#         "Hire Year": 2017,
#         "Rehire Year": null,
#         "Termination Year": 2018.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 3.8020367253
#     },
#     {
#         "Payroll Name": "Agee, Ronald",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Armed Officer",
#         "Hire Date": 1520812800000,
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": 1546214400000,
#         "Position Start Date": 1520812800000,
#         "Termination Reason Description": "PayCom Conversion",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000825",
#         "count": 1,
#         "Hire Year": 2018,
#         "Rehire Year": null,
#         "Termination Year": 2018.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.6959450072
#     },
#     {
#         "Payroll Name": "Agnew, Vanika",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": 1535328000000,
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": 1546214400000,
#         "Position Start Date": 1535328000000,
#         "Termination Reason Description": "PayCom Conversion",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX001142",
#         "count": 1,
#         "Hire Year": 2018,
#         "Rehire Year": null,
#         "Termination Year": 2018.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.235986075
#     },
#     {
#         "Payroll Name": "Ailey, Billy Vaughndarryl",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": 1491436800000,
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": 1546214400000,
#         "Position Start Date": 1491436800000,
#         "Termination Reason Description": "PayCom Conversion",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000519",
#         "count": 1,
#         "Hire Year": 2017,
#         "Rehire Year": null,
#         "Termination Year": 2018.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 3.6268142749
#     },
#     {
#         "Payroll Name": "Ajayi, Denise",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": 1528934400000,
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": 1531353600000,
#         "Position Start Date": 1528934400000,
#         "Termination Reason Description": "Import Created Action",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX001025",
#         "count": 1,
#         "Hire Year": 2018,
#         "Rehire Year": null,
#         "Termination Year": 2018.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.4385870333
#     },
#     {
#         "Payroll Name": "Akinkunmi, Akintunde",
#         "Business Unit Description": "Darryl's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": 1579737600000,
#         "Hire Reason Description": "New Position",
#         "Rehire Date": null,
#         "Termination Date": null,
#         "Position Start Date": 1579737600000,
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX004257",
#         "count": 1,
#         "Hire Year": 2020,
#         "Rehire Year": null,
#         "Termination Year": null,
#         "Hire Status": "New Hire",
#         "Years of Service": 0.8287307704
#     },
#     {
#         "Payroll Name": "Akons, Edward",
#         "Business Unit Description": "Darryl's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Armed Security Officer",
#         "Hire Date": 1288828800000,
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": null,
#         "Position Start Date": 1288828800000,
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000114",
#         "count": 1,
#         "Hire Year": 2010,
#         "Rehire Year": null,
#         "Termination Year": null,
#         "Hire Status": "New Hire",
#         "Years of Service": 10.0470743707
#     },
#     {
#         "Payroll Name": "Alcaraz-Gomez, Johnny",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Armed Officer",
#         "Hire Date": 1523232000000,
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": 1546214400000,
#         "Position Start Date": 1523232000000,
#         "Termination Reason Description": "PayCom Conversion",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000880",
#         "count": 1,
#         "Hire Year": 2018,
#         "Rehire Year": null,
#         "Termination Year": 2018.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.6192851852
#     },
#     {
#         "Payroll Name": "Alde, William",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": 1511136000000,
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": 1517616000000,
#         "Position Start Date": 1511136000000,
#         "Termination Reason Description": "Import Created Action",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000695",
#         "count": 1,
#         "Hire Year": 2017,
#         "Rehire Year": null,
#         "Termination Year": 2018.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 3.0025842954
#     },
#     {
#         "Payroll Name": "Aldridge, Courtney",
#         "Business Unit Description": "Darryl's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": 1590019200000,
#         "Hire Reason Description": "New Position",
#         "Rehire Date": null,
#         "Termination Date": 1595894400000,
#         "Position Start Date": 1590019200000,
#         "Termination Reason Description": "Abandoned Job",
#         "Voluntary/Involuntary Termination Flag": "Involuntary",
#         "Position ID": "MVX001646",
#         "count": 1,
#         "Hire Year": 2020,
#         "Rehire Year": null,
#         "Termination Year": 2020.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 0.5029265268
#     },
#     {
#         "Payroll Name": "Alexander, Brenda Lee",
#         "Business Unit Description": "Steve's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Armed Security Officer",
#         "Hire Date": 1483660800000,
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": null,
#         "Position Start Date": 1483660800000,
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000422",
#         "count": 1,
#         "Hire Year": 2017,
#         "Rehire Year": null,
#         "Termination Year": null,
#         "Hire Status": "New Hire",
#         "Years of Service": 3.8732208457
#     },
#     {
#         "Payroll Name": "Alexander, DeAndre Ramone",
#         "Business Unit Description": "Darryl's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": 1577059200000,
#         "Hire Reason Description": "New Position",
#         "Rehire Date": null,
#         "Termination Date": 1582416000000,
#         "Position Start Date": 1577059200000,
#         "Termination Reason Description": "Voluntary Resignation",
#         "Voluntary/Involuntary Termination Flag": "Voluntary",
#         "Position ID": "MVX004147",
#         "count": 1,
#         "Hire Year": 2019,
#         "Rehire Year": null,
#         "Termination Year": 2020.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 0.9136041448
#     },
#     {
#         "Payroll Name": "Alexander, Devante",
#         "Business Unit Description": "Odom's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Corporal",
#         "Hire Date": 1578355200000,
#         "Hire Reason Description": "New Position",
#         "Rehire Date": null,
#         "Termination Date": null,
#         "Position Start Date": 1598140800000,
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX004155",
#         "count": 1,
#         "Hire Year": 2020,
#         "Rehire Year": null,
#         "Termination Year": null,
#         "Hire Status": "Rehire",
#         "Years of Service": 0.872536383
#     },
#     {
#         "Payroll Name": "Alexander, Jameya",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": 1539734400000,
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": 1546214400000,
#         "Position Start Date": 1539734400000,
#         "Termination Reason Description": "PayCom Conversion",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX001215",
#         "count": 1,
#         "Hire Year": 2018,
#         "Rehire Year": null,
#         "Termination Year": 2018.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.0963556849
#     },
#     {
#         "Payroll Name": "Alexander, Katina",
#         "Business Unit Description": "Alicia's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Armed Security Officer",
#         "Hire Date": 1515542400000,
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": 1571011200000,
#         "Position Start Date": 1515542400000,
#         "Termination Reason Description": "Personal",
#         "Voluntary/Involuntary Termination Flag": "Voluntary",
#         "Position ID": "MVX000727",
#         "count": 1,
#         "Hire Year": 2018,
#         "Rehire Year": null,
#         "Termination Year": 2019.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.8629539053
#     },
#     {
#         "Payroll Name": "Alexander, Keith",
#         "Business Unit Description": "Darryl's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": 1593043200000,
#         "Hire Reason Description": "New Position",
#         "Rehire Date": null,
#         "Termination Date": 1598572800000,
#         "Position Start Date": 1593043200000,
#         "Termination Reason Description": "Abandoned Job",
#         "Voluntary/Involuntary Termination Flag": "Involuntary",
#         "Position ID": "MVX001889",
#         "count": 1,
#         "Hire Year": 2020,
#         "Rehire Year": null,
#         "Termination Year": 2020.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 0.4071017492
#     },
#     {
#         "Payroll Name": "Alexander, Sabrina",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": 1524441600000,
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": 1531353600000,
#         "Position Start Date": 1524441600000,
#         "Termination Reason Description": "Import Created Action",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000892",
#         "count": 1,
#         "Hire Year": 2018,
#         "Rehire Year": null,
#         "Termination Year": 2018.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.5809552742
#     },
#     {
#         "Payroll Name": "Alexander, Sierra",
#         "Business Unit Description": "Steve's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": 1538956800000,
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": 1559347200000,
#         "Position Start Date": 1538956800000,
#         "Termination Reason Description": "Voluntary Resignation",
#         "Voluntary/Involuntary Termination Flag": "Voluntary",
#         "Position ID": "MVX001195",
#         "count": 1,
#         "Hire Year": 2018,
#         "Rehire Year": null,
#         "Termination Year": 2019.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.120996342
#     },
#     {
#         "Payroll Name": "Ali, Mohamed Abdirashid",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": 1527811200000,
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": 1546214400000,
#         "Position Start Date": 1527811200000,
#         "Termination Reason Description": "PayCom Conversion",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX001000",
#         "count": 1,
#         "Hire Year": 2018,
#         "Rehire Year": null,
#         "Termination Year": 2018.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.4741790935
#     },
#     {
#         "Payroll Name": "Allen, Arlisa Mona",
#         "Business Unit Description": "Steve's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": 1476230400000,
#         "Hire Reason Description": null,
#         "Rehire Date": 1599091200000,
#         "Termination Date": null,
#         "Position Start Date": 1599091200000,
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000364",
#         "count": 1,
#         "Hire Year": 2016,
#         "Rehire Year": 2020.0,
#         "Termination Year": null,
#         "Hire Status": "Rehire",
#         "Years of Service": 4.1086760134
#     },
#     {
#         "Payroll Name": "Allen, Christie",
#         "Business Unit Description": "Steve's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": 1579824000000,
#         "Hire Reason Description": "New Position",
#         "Rehire Date": null,
#         "Termination Date": 1580256000000,
#         "Position Start Date": 1579824000000,
#         "Termination Reason Description": "Voluntary Resignation",
#         "Voluntary/Involuntary Termination Flag": "Voluntary",
#         "Position ID": "MVX004201",
#         "count": 1,
#         "Hire Year": 2020,
#         "Rehire Year": null,
#         "Termination Year": 2020.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 0.8259929196
#     },
#     {
#         "Payroll Name": "Allen, Christopher",
#         "Business Unit Description": "Darryl's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Armed Security Officer",
#         "Hire Date": 1457913600000,
#         "Hire Reason Description": null,
#         "Rehire Date": 1488844800000,
#         "Termination Date": 1561334400000,
#         "Position Start Date": 1457913600000,
#         "Termination Reason Description": "Voluntary Resignation",
#         "Voluntary/Involuntary Termination Flag": "Voluntary",
#         "Position ID": "MVX000278",
#         "count": 1,
#         "Hire Year": 2016,
#         "Rehire Year": 2017.0,
#         "Termination Year": 2019.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 4.6891003803
#     },
#     {
#         "Payroll Name": "Allen, Cortney",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Armed Officer",
#         "Hire Date": 1537747200000,
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": 1546214400000,
#         "Position Start Date": 1537747200000,
#         "Termination Reason Description": "PayCom Conversion",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX001191",
#         "count": 1,
#         "Hire Year": 2018,
#         "Rehire Year": null,
#         "Termination Year": 2018.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.159326253
#     },
#     {
#         "Payroll Name": "Allen, Dantrell",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Armed Officer",
#         "Hire Date": 1455235200000,
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": 1546214400000,
#         "Position Start Date": 1455235200000,
#         "Termination Reason Description": "PayCom Conversion",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000266",
#         "count": 1,
#         "Hire Year": 2016,
#         "Rehire Year": null,
#         "Termination Year": 2018.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 4.7739737547
#     },
#     {
#         "Payroll Name": "Allen, Tiffany Danielle",
#         "Business Unit Description": "Odom's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": 1603670400000,
#         "Hire Reason Description": "New Position",
#         "Rehire Date": null,
#         "Termination Date": null,
#         "Position Start Date": 1603670400000,
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX002131",
#         "count": 1,
#         "Hire Year": 2020,
#         "Rehire Year": null,
#         "Termination Year": null,
#         "Hire Status": "New Hire",
#         "Years of Service": 0.0703461024
#     },
#     {
#         "Payroll Name": "Allen, Trevonne",
#         "Business Unit Description": "Odom's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": 1600300800000,
#         "Hire Reason Description": "New Position",
#         "Rehire Date": null,
#         "Termination Date": null,
#         "Position Start Date": 1600300800000,
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX002052",
#         "count": 1,
#         "Hire Year": 2020,
#         "Rehire Year": null,
#         "Termination Year": null,
#         "Hire Status": "New Hire",
#         "Years of Service": 0.1771222831
#     },
#     {
#         "Payroll Name": "Alston, Barron R",
#         "Business Unit Description": "Odom's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Police Officer",
#         "Hire Date": 1341705600000,
#         "Hire Reason Description": "Existing Position",
#         "Rehire Date": 1561939200000,
#         "Termination Date": null,
#         "Position Start Date": 1341705600000,
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000133",
#         "count": 1,
#         "Hire Year": 2012,
#         "Rehire Year": 2019.0,
#         "Termination Year": null,
#         "Hire Status": "New Hire",
#         "Years of Service": 8.371509689
#     },
#     {
#         "Payroll Name": "Alston, Barron R",
#         "Business Unit Description": "Odom's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Police Officer",
#         "Hire Date": 1341705600000,
#         "Hire Reason Description": "Existing Position",
#         "Rehire Date": null,
#         "Termination Date": null,
#         "Position Start Date": 1554076800000,
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "RJS000133",
#         "count": 1,
#         "Hire Year": 2012,
#         "Rehire Year": null,
#         "Termination Year": null,
#         "Hire Status": "Rehire",
#         "Years of Service": 8.371509689
#     },
#     {
#         "Payroll Name": "Alvarez, Javier",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Police Officer Sworn Peace Officer",
#         "Hire Date": 1522540800000,
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": 1546214400000,
#         "Position Start Date": 1522540800000,
#         "Termination Reason Description": "PayCom Conversion",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000856",
#         "count": 1,
#         "Hire Year": 2018,
#         "Rehire Year": null,
#         "Termination Year": 2018.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.6411879915
#     },
#     {
#         "Payroll Name": "Amick, Tatanna",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": 1525651200000,
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": 1546214400000,
#         "Position Start Date": 1525651200000,
#         "Termination Reason Description": "PayCom Conversion",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000964",
#         "count": 1,
#         "Hire Year": 2018,
#         "Rehire Year": null,
#         "Termination Year": 2018.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.5426253632
#     },
#     {
#         "Payroll Name": "Anderson, Antoine",
#         "Business Unit Description": "Alicia's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Police Officer",
#         "Hire Date": 1539302400000,
#         "Hire Reason Description": "New Position",
#         "Rehire Date": null,
#         "Termination Date": 1561939200000,
#         "Position Start Date": 1539302400000,
#         "Termination Reason Description": "Reorganization",
#         "Voluntary/Involuntary Termination Flag": "Voluntary",
#         "Position ID": "MVX001209",
#         "count": 1,
#         "Hire Year": 2018,
#         "Rehire Year": null,
#         "Termination Year": 2019.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.1100449388
#     },
#     {
#         "Payroll Name": "Anderson, Antoine",
#         "Business Unit Description": "Steve's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Police Officer",
#         "Hire Date": 1539302400000,
#         "Hire Reason Description": "New Position",
#         "Rehire Date": 1585267200000,
#         "Termination Date": 1595894400000,
#         "Position Start Date": 1554076800000,
#         "Termination Reason Description": "Abandoned Job",
#         "Voluntary/Involuntary Termination Flag": "Involuntary",
#         "Position ID": "RJS001209",
#         "count": 1,
#         "Hire Year": 2018,
#         "Rehire Year": 2020.0,
#         "Termination Year": 2020.0,
#         "Hire Status": "Rehire",
#         "Years of Service": 2.1100449388
#     },
#     {
#         "Payroll Name": "Anderson, Dante",
#         "Business Unit Description": "Steve's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Armed Security Officer",
#         "Hire Date": 1517961600000,
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": 1563926400000,
#         "Position Start Date": 1517961600000,
#         "Termination Reason Description": "Voluntary Resignation",
#         "Voluntary/Involuntary Termination Flag": "Voluntary",
#         "Position ID": "MVX000768",
#         "count": 1,
#         "Hire Year": 2018,
#         "Rehire Year": null,
#         "Termination Year": 2019.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.7862940832
#     },
#     {
#         "Payroll Name": "Anderson, Dovien",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Armed Officer",
#         "Hire Date": 1320105600000,
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": 1546214400000,
#         "Position Start Date": 1320105600000,
#         "Termination Reason Description": "PayCom Conversion",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000123",
#         "count": 1,
#         "Hire Year": 2011,
#         "Rehire Year": null,
#         "Termination Year": 2018.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 9.0559723858
#     },
#     {
#         "Payroll Name": "Anderson, Jadonna Shontrese",
#         "Business Unit Description": "Steve's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Armed Security Officer",
#         "Hire Date": 1491177600000,
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": null,
#         "Position Start Date": 1491177600000,
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000507",
#         "count": 1,
#         "Hire Year": 2017,
#         "Rehire Year": null,
#         "Termination Year": null,
#         "Hire Status": "New Hire",
#         "Years of Service": 3.6350278272
#     },
#     {
#         "Payroll Name": "Anderson, John",
#         "Business Unit Description": "Darryl's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": 1598313600000,
#         "Hire Reason Description": "New Position",
#         "Rehire Date": null,
#         "Termination Date": null,
#         "Position Start Date": 1598313600000,
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX002015",
#         "count": 1,
#         "Hire Year": 2020,
#         "Rehire Year": null,
#         "Termination Year": null,
#         "Hire Status": "New Hire",
#         "Years of Service": 0.2400928512
#     },
#     {
#         "Payroll Name": "Anderson, Jonathan",
#         "Business Unit Description": "Alicia's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": 1556496000000,
#         "Hire Reason Description": "Existing Position",
#         "Rehire Date": null,
#         "Termination Date": 1559347200000,
#         "Position Start Date": 1556496000000,
#         "Termination Reason Description": "Abandoned Job",
#         "Voluntary/Involuntary Termination Flag": "Involuntary",
#         "Position ID": "MVX001578",
#         "count": 1,
#         "Hire Year": 2019,
#         "Rehire Year": null,
#         "Termination Year": 2019.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 1.5652126322
#     },
#     {
#         "Payroll Name": "Anderson, Kendrick Broshaun",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Armed Officer",
#         "Hire Date": 1487808000000,
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": 1546214400000,
#         "Position Start Date": 1487808000000,
#         "Termination Reason Description": "PayCom Conversion",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000452",
#         "count": 1,
#         "Hire Year": 2017,
#         "Rehire Year": null,
#         "Termination Year": 2018.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 3.7418040079
#     },
#     {
#         "Payroll Name": "Anderson, Kentriss",
#         "Business Unit Description": "Odom's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": 1593043200000,
#         "Hire Reason Description": "New Position",
#         "Rehire Date": null,
#         "Termination Date": null,
#         "Position Start Date": 1593043200000,
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX001892",
#         "count": 1,
#         "Hire Year": 2020,
#         "Rehire Year": null,
#         "Termination Year": null,
#         "Hire Status": "New Hire",
#         "Years of Service": 0.4071017492
#     },
#     {
#         "Payroll Name": "Anderson, Mable",
#         "Business Unit Description": "Darryl's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": 1559174400000,
#         "Hire Reason Description": "Existing Position",
#         "Rehire Date": null,
#         "Termination Date": null,
#         "Position Start Date": 1559174400000,
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX001682",
#         "count": 1,
#         "Hire Year": 2019,
#         "Rehire Year": null,
#         "Termination Year": null,
#         "Hire Status": "New Hire",
#         "Years of Service": 1.4803392578
#     },
#     {
#         "Payroll Name": "Anderson, Odessa",
#         "Business Unit Description": "Steve's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": 1559174400000,
#         "Hire Reason Description": "Existing Position",
#         "Rehire Date": null,
#         "Termination Date": 1582416000000,
#         "Position Start Date": 1559174400000,
#         "Termination Reason Description": "Voluntary Resignation",
#         "Voluntary/Involuntary Termination Flag": "Voluntary",
#         "Position ID": "MVX001678",
#         "count": 1,
#         "Hire Year": 2019,
#         "Rehire Year": null,
#         "Termination Year": 2020.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 1.4803392578
#     },
#     {
#         "Payroll Name": "Anderson, Robert",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": 1462406400000,
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": 1531440000000,
#         "Position Start Date": 1462406400000,
#         "Termination Reason Description": "Import Created Action",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000299",
#         "count": 1,
#         "Hire Year": 2016,
#         "Rehire Year": null,
#         "Termination Year": 2018.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 4.5467321394
#     },
#     {
#         "Payroll Name": "Anderson, Shaquana Denise",
#         "Business Unit Description": "Steve's Region",
#         "Position Status": "Leave",
#         "Job Title Description": "Armed Security Officer",
#         "Hire Date": 1476316800000,
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": null,
#         "Position Start Date": 1476316800000,
#         "Termination Reason Description": null,
# ...
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": null,
#         "Position Start Date": 1485475200000,
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000434",
#         "count": 1,
#         "Hire Year": 2017,
#         "Rehire Year": null,
#         "Termination Year": null,
#         "Hire Status": "New Hire",
#         "Years of Service": 3.8157259792
#     },
#     {
#         "Payroll Name": "Wrobel, Adrian",
#         "Business Unit Description": "Alicia's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Armed Security Officer",
#         "Hire Date": 1499904000000,
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": null,
#         "Position Start Date": 1499904000000,
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000606",
#         "count": 1,
#         "Hire Year": 2017,
#         "Rehire Year": null,
#         "Termination Year": null,
#         "Hire Status": "New Hire",
#         "Years of Service": 3.3585048977
#     },
#     {
#         "Payroll Name": "Yalley, Chrishana",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": 1536192000000,
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": 1546214400000,
#         "Position Start Date": 1536192000000,
#         "Termination Reason Description": "PayCom Conversion",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX001156",
#         "count": 1,
#         "Hire Year": 2018,
#         "Rehire Year": null,
#         "Termination Year": 2018.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.2086075671
#     },
#     {
#         "Payroll Name": "Yarbrough, Alexus",
#         "Business Unit Description": "Darryl's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Non Commission Officer",
#         "Hire Date": 1596931200000,
#         "Hire Reason Description": "New Position",
#         "Rehire Date": null,
#         "Termination Date": null,
#         "Position Start Date": 1596931200000,
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX001998",
#         "count": 1,
#         "Hire Year": 2020,
#         "Rehire Year": null,
#         "Termination Year": null,
#         "Hire Status": "New Hire",
#         "Years of Service": 0.2838984638
#     },
#     {
#         "Payroll Name": "Yates, Passion",
#         "Business Unit Description": "Steve's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": 1554076800000,
#         "Hire Reason Description": "Existing Position",
#         "Rehire Date": null,
#         "Termination Date": 1564963200000,
#         "Position Start Date": 1554076800000,
#         "Termination Reason Description": "Voluntary Resignation",
#         "Voluntary/Involuntary Termination Flag": "Voluntary",
#         "Position ID": "MVX001557",
#         "count": 1,
#         "Hire Year": 2019,
#         "Rehire Year": null,
#         "Termination Year": 2019.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 1.6418724542
#     },
#     {
#         "Payroll Name": "Yerow, Abdi Hassan",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": 1526342400000,
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": 1531180800000,
#         "Position Start Date": 1526342400000,
#         "Termination Reason Description": "Import Created Action",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000991",
#         "count": 1,
#         "Hire Year": 2018,
#         "Rehire Year": null,
#         "Termination Year": 2018.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.5207225569
#     },
#     {
#         "Payroll Name": "Young, Debra",
#         "Business Unit Description": "Odom's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": 1581897600000,
#         "Hire Reason Description": "New Position",
#         "Rehire Date": null,
#         "Termination Date": 1591056000000,
#         "Position Start Date": 1581897600000,
#         "Termination Reason Description": "Abandoned Job",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX004273",
#         "count": 1,
#         "Hire Year": 2020,
#         "Rehire Year": null,
#         "Termination Year": 2020.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 0.7602845007
#     },
#     {
#         "Payroll Name": "Young, DejAsia",
#         "Business Unit Description": "Odom's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Armed Security Officer",
#         "Hire Date": 1572393600000,
#         "Hire Reason Description": "New Position",
#         "Rehire Date": 1587081600000,
#         "Termination Date": null,
#         "Position Start Date": 1587081600000,
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": "Voluntary",
#         "Position ID": "MVX004094",
#         "count": 1,
#         "Hire Year": 2019,
#         "Rehire Year": 2020.0,
#         "Termination Year": null,
#         "Hire Status": "Rehire",
#         "Years of Service": 1.0614480873
#     },
#     {
#         "Payroll Name": "Young, Devontae",
#         "Business Unit Description": "Darryl's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": 1591315200000,
#         "Hire Reason Description": "New Position",
#         "Rehire Date": null,
#         "Termination Date": null,
#         "Position Start Date": 1591315200000,
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX001859",
#         "count": 1,
#         "Hire Year": 2020,
#         "Rehire Year": null,
#         "Termination Year": null,
#         "Hire Status": "New Hire",
#         "Years of Service": 0.461858765
#     },
#     {
#         "Payroll Name": "Young, Dominique Latoya",
#         "Business Unit Description": "Steve's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": 1574640000000,
#         "Hire Reason Description": "New Position",
#         "Rehire Date": null,
#         "Termination Date": 1580169600000,
#         "Position Start Date": 1574640000000,
#         "Termination Reason Description": "Voluntary Resignation",
#         "Voluntary/Involuntary Termination Flag": "Voluntary",
#         "Position ID": "MVX004116",
#         "count": 1,
#         "Hire Year": 2019,
#         "Rehire Year": null,
#         "Termination Year": 2020.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 0.9902639669
#     },
#     {
#         "Payroll Name": "Young, Erica",
#         "Business Unit Description": "Darryl's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Armed Security Officer",
#         "Hire Date": 1549238400000,
#         "Hire Reason Description": "New Position",
#         "Rehire Date": null,
#         "Termination Date": null,
#         "Position Start Date": 1549238400000,
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX001453",
#         "count": 1,
#         "Hire Year": 2019,
#         "Rehire Year": null,
#         "Termination Year": null,
#         "Hire Status": "New Hire",
#         "Years of Service": 1.7951920983
#     },
#     {
#         "Payroll Name": "Young, Erin",
#         "Business Unit Description": "Administration",
#         "Position Status": "Active",
#         "Job Title Description": "Marketing & Sales Coordinator",
#         "Hire Date": 1548633600000,
#         "Hire Reason Description": "New Position",
#         "Rehire Date": 1595203200000,
#         "Termination Date": null,
#         "Position Start Date": 1601769600000,
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX001424",
#         "count": 1,
#         "Hire Year": 2019,
#         "Rehire Year": 2020.0,
#         "Termination Year": null,
#         "Hire Status": "Rehire",
#         "Years of Service": 1.8143570538
#     },
#     {
#         "Payroll Name": "Young, Javan",
#         "Business Unit Description": "Darryl's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Armed Security Officer",
#         "Hire Date": 1458518400000,
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": null,
#         "Position Start Date": 1458518400000,
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000280",
#         "count": 1,
#         "Hire Year": 2016,
#         "Rehire Year": null,
#         "Termination Year": null,
#         "Hire Status": "New Hire",
#         "Years of Service": 4.6699354248
#     },
#     {
#         "Payroll Name": "Young, Marshawn",
#         "Business Unit Description": "Alicia's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": 1549238400000,
#         "Hire Reason Description": "New Position",
#         "Rehire Date": null,
#         "Termination Date": 1582588800000,
#         "Position Start Date": 1549238400000,
#         "Termination Reason Description": "Abandoned Job",
#         "Voluntary/Involuntary Termination Flag": "Involuntary",
#         "Position ID": "MVX001437",
#         "count": 1,
#         "Hire Year": 2019,
#         "Rehire Year": null,
#         "Termination Year": 2020.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 1.7951920983
#     },
#     {
#         "Payroll Name": "Young, Raven A",
#         "Business Unit Description": "Odom's Region",
#         "Position Status": "Leave",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": 1580688000000,
#         "Hire Reason Description": "New Position",
#         "Rehire Date": null,
#         "Termination Date": null,
#         "Position Start Date": 1580688000000,
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX004230",
#         "count": 1,
#         "Hire Year": 2020,
#         "Rehire Year": null,
#         "Termination Year": null,
#         "Hire Status": "New Hire",
#         "Years of Service": 0.7986144118
#     },
#     {
#         "Payroll Name": "Youngblood, Desmond",
#         "Business Unit Description": "Darryl's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": 1593561600000,
#         "Hire Reason Description": "New Position",
#         "Rehire Date": null,
#         "Termination Date": null,
#         "Position Start Date": 1593561600000,
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX001901",
#         "count": 1,
#         "Hire Year": 2020,
#         "Rehire Year": null,
#         "Termination Year": null,
#         "Hire Status": "New Hire",
#         "Years of Service": 0.3906746445
#     },
#     {
#         "Payroll Name": "Younger, Kameron",
#         "Business Unit Description": "Steve's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Armed Security Officer",
#         "Hire Date": 1442880000000,
#         "Hire Reason Description": null,
#         "Rehire Date": 1529971200000,
#         "Termination Date": null,
#         "Position Start Date": 1442880000000,
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000209",
#         "count": 1,
#         "Hire Year": 2015,
#         "Rehire Year": 2018.0,
#         "Termination Year": null,
#         "Hire Status": "New Hire",
#         "Years of Service": 5.1654864172
#     },
#     {
#         "Payroll Name": "Zarif, Alexis",
#         "Business Unit Description": "Steve's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": 1532908800000,
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": null,
#         "Position Start Date": 1532908800000,
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX001095",
#         "count": 1,
#         "Hire Year": 2018,
#         "Rehire Year": null,
#         "Termination Year": null,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.3126458971
#     },
#     {
#         "Payroll Name": "Zayas, Benjamin Joseph",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Armed Officer",
#         "Hire Date": 1479168000000,
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": 1522800000000,
#         "Position Start Date": 1479168000000,
#         "Termination Reason Description": "Import Created Action",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000392",
#         "count": 1,
#         "Hire Year": 2016,
#         "Rehire Year": null,
#         "Termination Year": 2018.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 4.0155890866
#     },
#     {
#         "Payroll Name": "Zayas, Reina",
#         "Business Unit Description": "Administration",
#         "Position Status": "Active",
#         "Job Title Description": "Business Administrator",
#         "Hire Date": 1590105600000,
#         "Hire Reason Description": "New Position",
#         "Rehire Date": null,
#         "Termination Date": null,
#         "Position Start Date": 1590105600000,
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "RJS004315",
#         "count": 1,
#         "Hire Year": 2020,
#         "Rehire Year": null,
#         "Termination Year": null,
#         "Hire Status": "New Hire",
#         "Years of Service": 0.500188676
#     },
#     {
#         "Payroll Name": "Zayas, Timothy G",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Armed Officer",
#         "Hire Date": 1479427200000,
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": 1531440000000,
#         "Position Start Date": 1479427200000,
#         "Termination Reason Description": "Import Created Action",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000395",
#         "count": 1,
#         "Hire Year": 2016,
#         "Rehire Year": null,
#         "Termination Year": 2018.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 4.0073755343
#     },
#     {
#         "Payroll Name": "Zeigler, Mary R",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": 1489968000000,
#         "Hire Reason Description": null,
#         "Rehire Date": null,
#         "Termination Date": 1531353600000,
#         "Position Start Date": 1489968000000,
#         "Termination Reason Description": "Import Created Action",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000486",
#         "count": 1,
#         "Hire Year": 2017,
#         "Rehire Year": null,
#         "Termination Year": 2018.0,
#         "Hire Status": "New Hire",
#         "Years of Service": 3.6733577383
#     }
# ]

# %% [markdown]
# "Position Status" filter for 'Active'  /  Distinct Count (unique_values()) {"Payroll Name"} = this tells me how many people are working
#
# find how many people have a year or greater of "Years of Service" = retention people
#
# retention people / Distinct Count (unique_values()) {"Payroll Name"}

# %%
data.count()  #['Hire Status'].value_counts()
# Out:
# Payroll Name                              2559
# Business Unit Description                 1822
# Position Status                           2559
# Job Title Description                     2444
# Hire Date                                 2559
# Hire Reason Description                   1308
# Rehire Date                               2559
# Termination Date                          2559
# Position Start Date                       2559
# Termination Reason Description            1667
# Voluntary/Involuntary Termination Flag     870
# Position ID                               2559
# count                                     2559
# Hire Status                               2559
# Years of Service                          2559
# dtype: int64

# %%
data.loc[data['Termination Date'] != 0,:]
# Out:
#                  Payroll Name Business Unit Description Position Status  \
# 1                Abdi, Gibril                       NaN      Terminated
# 2        Abdi, Suleiman Gulan                       NaN      Terminated
# 3            Abdullah, Maizar           Darryl's Region      Terminated
# 4            Abdullah, Rammah           Darryl's Region      Terminated
# 5         Aboyade-Cole, Toyin                       NaN      Terminated
# ...                       ...                       ...             ...
# 2546  Young, Dominique Latoya            Steve's Region      Terminated
# 2550          Young, Marshawn           Alicia's Region      Terminated
# 2555   Zayas, Benjamin Joseph                       NaN      Terminated
# 2557         Zayas, Timothy G                       NaN      Terminated
# 2558          Zeigler, Mary R                       NaN      Terminated
#
#          Job Title Description   Hire Date Hire Reason Description  \
# 1              Unarmed Officer  2018-04-27                     NaN
# 2              Unarmed Officer  2018-06-05                     NaN
# 3     Unarmed Security Officer  2019-02-20            New Position
# 4     Unarmed Security Officer  2019-02-20            New Position
# 5     Unarmed Security Officer  2018-03-12                     NaN
# ...                        ...         ...                     ...
# 2546           Unarmed Officer  2019-11-25            New Position
# 2550  Unarmed Security Officer  2019-02-04            New Position
# 2555             Armed Officer  2016-11-15                     NaN
# 2557             Armed Officer  2016-11-18                     NaN
# 2558           Unarmed Officer  2017-03-20                     NaN
#
#      Rehire Date Termination Date Position Start Date  \
# 1              0       2018-07-10          2018-04-27
# 2              0       2018-07-10          2018-06-05
# 3              0       2019-04-12          2019-02-20
# 4              0       2019-04-12          2019-02-20
# 5              0       2018-07-03          2018-03-12
# ...          ...              ...                 ...
# 2546           0       2020-01-28          2019-11-25
# 2550           0       2020-02-25          2019-02-04
# 2555           0       2018-04-04          2016-11-15
# 2557           0       2018-07-13          2016-11-18
# 2558           0       2018-07-12          2017-03-20
#
#      Termination Reason Description Voluntary/Involuntary Termination Flag  \
# 1                          Personal                            Involuntary
# 2             Import Created Action                                    NaN
# 3             Voluntary Resignation                              Voluntary
# 4             Voluntary Resignation                              Voluntary
# 5             Import Created Action                                    NaN
# ...                             ...                                    ...
# 2546          Voluntary Resignation                              Voluntary
# 2550                  Abandoned Job                            Involuntary
# 2555          Import Created Action                                    NaN
# 2557          Import Created Action                                    NaN
# 2558          Import Created Action                                    NaN
#
#      Position ID  count Hire Status  Years of Service
# 1      MVX000918      1    New Hire          2.569577
# 2      MVX001002      1    New Hire          2.462801
# 3      MVX001493      1    New Hire          1.750960
# 4      MVX001495      1    New Hire          1.750960
# 5      MVX000820      1    New Hire          2.695518
# ...          ...    ...         ...               ...
# 2546   MVX004116      1    New Hire          0.989837
# 2550   MVX001437      1    New Hire          1.794765
# 2555   MVX000392      1    New Hire          4.015162
# 2557   MVX000395      1    New Hire          4.006949
# 2558   MVX000486      1    New Hire          3.672931
#
# [1667 rows x 15 columns]

# %%
data.loc[data['Hire Date'] != 0,:]
# Out:
#                 Payroll Name Business Unit Description Position Status  \
# 0             Aaron, Charity           Darryl's Region          Active
# 1               Abdi, Gibril                       NaN      Terminated
# 2       Abdi, Suleiman Gulan                       NaN      Terminated
# 3           Abdullah, Maizar           Darryl's Region      Terminated
# 4           Abdullah, Rammah           Darryl's Region      Terminated
# ...                      ...                       ...             ...
# 2554           Zarif, Alexis            Steve's Region          Active
# 2555  Zayas, Benjamin Joseph                       NaN      Terminated
# 2556            Zayas, Reina            Administration          Active
# 2557        Zayas, Timothy G                       NaN      Terminated
# 2558         Zeigler, Mary R                       NaN      Terminated
#
#          Job Title Description   Hire Date Hire Reason Description  \
# 0     Unarmed Security Officer  2020-07-20            New Position
# 1              Unarmed Officer  2018-04-27                     NaN
# 2              Unarmed Officer  2018-06-05                     NaN
# 3     Unarmed Security Officer  2019-02-20            New Position
# 4     Unarmed Security Officer  2019-02-20            New Position
# ...                        ...         ...                     ...
# 2554  Unarmed Security Officer  2018-07-30                     NaN
# 2555             Armed Officer  2016-11-15                     NaN
# 2556    Business Administrator  2020-05-22            New Position
# 2557             Armed Officer  2016-11-18                     NaN
# 2558           Unarmed Officer  2017-03-20                     NaN
#
#      Rehire Date Termination Date Position Start Date  \
# 0              0                0          2020-07-20
# 1              0       2018-07-10          2018-04-27
# 2              0       2018-07-10          2018-06-05
# 3              0       2019-04-12          2019-02-20
# 4              0       2019-04-12          2019-02-20
# ...          ...              ...                 ...
# 2554           0                0          2018-07-30
# 2555           0       2018-04-04          2016-11-15
# 2556           0                0          2020-05-22
# 2557           0       2018-07-13          2016-11-18
# 2558           0       2018-07-12          2017-03-20
#
#      Termination Reason Description Voluntary/Involuntary Termination Flag  \
# 0                               NaN                                    NaN
# 1                          Personal                            Involuntary
# 2             Import Created Action                                    NaN
# 3             Voluntary Resignation                              Voluntary
# 4             Voluntary Resignation                              Voluntary
# ...                             ...                                    ...
# 2554                            NaN                                    NaN
# 2555          Import Created Action                                    NaN
# 2556                            NaN                                    NaN
# 2557          Import Created Action                                    NaN
# 2558          Import Created Action                                    NaN
#
#      Position ID  count Hire Status  Years of Service
# 0      MVX001936      1    New Hire          0.338229
# 1      MVX000918      1    New Hire          2.569577
# 2      MVX001002      1    New Hire          2.462801
# 3      MVX001493      1    New Hire          1.750960
# 4      MVX001495      1    New Hire          1.750960
# ...          ...    ...         ...               ...
# 2554   MVX001095      1    New Hire          2.312219
# 2555   MVX000392      1    New Hire          4.015162
# 2556   RJS004315      1    New Hire          0.499762
# 2557   MVX000395      1    New Hire          4.006949
# 2558   MVX000486      1    New Hire          3.672931
#
# [2559 rows x 15 columns]

# %%
data['Termination Date'
# Out:
# NaT           892
# 2018-12-31    287
# 2018-07-13     78
# 2020-02-23     75
# 2018-07-12     65
#              ...
# 2019-10-03      1
# 2020-05-08      1
# 2019-05-14      1
# 2020-02-03      1
# 2019-03-26      1
# Name: Termination Date, Length: 385, dtype: int64
