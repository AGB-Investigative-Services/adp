# %%
# DataFrame handlers
import pandas as pd
import os
import numpy as np

# json
import json

# Datetime Manager
from datetime import datetime as dt
from datetime import timedelta, time, date


# Reading CSV file
data = pd.read_csv('resources/data/HR Dash.csv', encoding='ISO-8859-1', low_memory=False)

# Adding count column for to automate groupby count function
data['count'] = 1

# Changing data types of date columns. Current format is read Timestamp
data['Position Start Date'] = pd.to_datetime(data['Position Start Date'])
data['Hire Date'] = pd.to_datetime(data['Hire Date'])
data['Rehire Date'] = pd.to_datetime(data['Rehire Date'])
data['Termination Date'] = pd.to_datetime(data['Termination Date'])

# Adding Columns
data['Hire Status'] = ''
data.loc[((data['Rehire Date'] == data['Position Start Date']) | (data['Hire Date'] < data['Position Start Date'])), 'Hire Status' ] = 'Rehire'
data.loc[data['Hire Status'] == '', 'Hire Status'] = 'New Hire'

# (https://docs.python.org/3.2/library/datetime.html)
# Adding Years of Service column and calulating the number of years worked
year = timedelta(days=365.25)
data['Years of Service'] = (dt.today() - data['Hire Date']) / year
data

# Formatting date columns to strings for JS Plotly Charts
data['Position Start Date'] = data['Position Start Date'].dt.strftime('%Y-%m-%d')
data['Hire Date'] = data['Hire Date'].dt.strftime('%Y-%m-%d')
data['Rehire Date'] = data['Rehire Date'].dt.strftime('%Y-%m-%d')
data['Termination Date'] = data['Termination Date'].dt.strftime('%Y-%m-%d')

# Removing "NaT" values from columns
data.loc[data['Rehire Date'] == 'NaT', 'Rehire Date'] = 0
data.loc[data['Termination Date'] == 'NaT', 'Termination Date'] = 0

data_json = data.to_json('resources/data/custom_hire_data.json', orient="records")
data_json = data.to_json(orient="records")
parsed = json.loads(data_json)
print(json.dumps(parsed, indent=4))
# Out:
# [
#     {
#         "Payroll Name": "Aaron, Charity",
#         "Business Unit Description": "Darryl's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": "2020-07-20",
#         "Hire Reason Description": "New Position",
#         "Rehire Date": 0,
#         "Termination Date": 0,
#         "Position Start Date": "2020-07-20",
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX001936",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 0.3216302631
#     },
#     {
#         "Payroll Name": "Abdi, Gibril",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": "2018-04-27",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": "2018-07-10",
#         "Position Start Date": "2018-04-27",
#         "Termination Reason Description": "Personal",
#         "Voluntary/Involuntary Termination Flag": "Involuntary",
#         "Position ID": "MVX000918",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.5529786546
#     },
#     {
#         "Payroll Name": "Abdi, Suleiman Gulan",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": "2018-06-05",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": "2018-07-10",
#         "Position Start Date": "2018-06-05",
#         "Termination Reason Description": "Import Created Action",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX001002",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.4462024739
#     },
#     {
#         "Payroll Name": "Abdullah, Maizar",
#         "Business Unit Description": "Darryl's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": "2019-02-20",
#         "Hire Reason Description": "New Position",
#         "Rehire Date": 0,
#         "Termination Date": "2019-04-12",
#         "Position Start Date": "2019-02-20",
#         "Termination Reason Description": "Voluntary Resignation",
#         "Voluntary/Involuntary Termination Flag": "Voluntary",
#         "Position ID": "MVX001493",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 1.7343612692
#     },
#     {
#         "Payroll Name": "Abdullah, Rammah",
#         "Business Unit Description": "Darryl's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": "2019-02-20",
#         "Hire Reason Description": "New Position",
#         "Rehire Date": 0,
#         "Termination Date": "2019-04-12",
#         "Position Start Date": "2019-02-20",
#         "Termination Reason Description": "Voluntary Resignation",
#         "Voluntary/Involuntary Termination Flag": "Voluntary",
#         "Position ID": "MVX001495",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 1.7343612692
#     },
#     {
#         "Payroll Name": "Aboyade-Cole, Toyin",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": "2018-03-12",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": "2018-07-03",
#         "Position Start Date": "2018-03-12",
#         "Termination Reason Description": "Import Created Action",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000820",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.6789197908
#     },
#     {
#         "Payroll Name": "Abraham, Tiara",
#         "Business Unit Description": "Darryl's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Armed Security Officer",
#         "Hire Date": "2020-01-24",
#         "Hire Reason Description": "New Position",
#         "Rehire Date": 0,
#         "Termination Date": "2020-07-30",
#         "Position Start Date": "2020-01-24",
#         "Termination Reason Description": "Abandoned Job",
#         "Voluntary/Involuntary Termination Flag": "Involuntary",
#         "Position ID": "MVX004190",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 0.8089677032
#     },
#     {
#         "Payroll Name": "Abron, Kenisha",
#         "Business Unit Description": "Administration",
#         "Position Status": "Terminated",
#         "Job Title Description": "Dispatch Supervisor",
#         "Hire Date": "2018-01-24",
#         "Hire Reason Description": "Existing Position",
#         "Rehire Date": "2019-01-11",
#         "Termination Date": "2019-11-08",
#         "Position Start Date": "2019-01-11",
#         "Termination Reason Description": "Personal",
#         "Voluntary/Involuntary Termination Flag": "Voluntary",
#         "Position ID": "MVX000749",
#         "count": 1,
#         "Hire Status": "Rehire",
#         "Years of Service": 2.8075987778
#     },
#     {
#         "Payroll Name": "Acevedo-Dixon, Elantra",
#         "Business Unit Description": "Steve's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Nicor Dispatcher",
#         "Hire Date": "2019-05-13",
#         "Hire Reason Description": "Existing Position",
#         "Rehire Date": 0,
#         "Termination Date": "2019-11-29",
#         "Position Start Date": "2019-05-13",
#         "Termination Reason Description": "Employee Quit after Client Rejection",
#         "Voluntary/Involuntary Termination Flag": "Voluntary",
#         "Position ID": "MVX001632",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 1.5098575047
#     },
#     {
#         "Payroll Name": "Acheampong, Clive",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": "2018-04-27",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": "2018-12-31",
#         "Position Start Date": "2018-04-27",
#         "Termination Reason Description": "PayCom Conversion",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000941",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.5529786546
#     },
#     {
#         "Payroll Name": "Adams, Amber",
#         "Business Unit Description": "Steve's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": "2018-08-13",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": 0,
#         "Position Start Date": "2018-08-13",
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX001123",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.2572907696
#     },
#     {
#         "Payroll Name": "Adams, Don E",
#         "Business Unit Description": "Steve's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Armed Security Officer",
#         "Hire Date": "2017-07-14",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": 0,
#         "Position Start Date": "2017-07-14",
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000612",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 3.3387418305
#     },
#     {
#         "Payroll Name": "Adams, Fletcher L",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": "2018-05-14",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": "2018-07-10",
#         "Position Start Date": "2018-05-14",
#         "Termination Reason Description": "Import Created Action",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000985",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.5064351912
#     },
#     {
#         "Payroll Name": "Adams, Jene",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": "2018-07-16",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": "2018-12-31",
#         "Position Start Date": "2018-07-16",
#         "Termination Reason Description": "PayCom Conversion",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX001068",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.3339505916
#     },
#     {
#         "Payroll Name": "Adams, Kamrin",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": "2018-05-14",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": "2018-08-15",
#         "Position Start Date": "2018-05-14",
#         "Termination Reason Description": "Import Created Action",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000978",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.5064351912
#     },
#     {
#         "Payroll Name": "Adams, Lotoninia",
#         "Business Unit Description": "Steve's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": "2018-03-26",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": "2019-04-20",
#         "Position Start Date": "2018-03-26",
#         "Termination Reason Description": "Voluntary Resignation",
#         "Voluntary/Involuntary Termination Flag": "Voluntary",
#         "Position ID": "MVX000838",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.6405898798
#     },
#     {
#         "Payroll Name": "Adams, Tiniya",
#         "Business Unit Description": "Darryl's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": "2020-03-09",
#         "Hire Reason Description": "New Position",
#         "Rehire Date": 0,
#         "Termination Date": 0,
#         "Position Start Date": "2020-03-09",
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX004319",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 0.6857644178
#     },
#     {
#         "Payroll Name": "Adams-Jones, Eboni",
#         "Business Unit Description": "Darryl's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Operations Coordinator",
#         "Hire Date": "2020-03-02",
#         "Hire Reason Description": "New Position",
#         "Rehire Date": 0,
#         "Termination Date": 0,
#         "Position Start Date": "2020-03-02",
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX004308",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 0.7049293733
#     },
#     {
#         "Payroll Name": "Adan, Abdi Marshale",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": "2018-08-09",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": "2018-12-31",
#         "Position Start Date": "2018-08-09",
#         "Termination Reason Description": "PayCom Conversion",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX001117",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.2682421727
#     },
#     {
#         "Payroll Name": "Adan, Bishar Noor",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": "2018-06-05",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": "2018-12-31",
#         "Position Start Date": "2018-06-05",
#         "Termination Reason Description": "PayCom Conversion",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX001005",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.4462024739
#     },
#     {
#         "Payroll Name": "Adan, Yahya Noor",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": "2018-06-05",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": "2018-08-09",
#         "Position Start Date": "2018-06-05",
#         "Termination Reason Description": "Import Created Action",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX001004",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.4462024739
#     },
#     {
#         "Payroll Name": "Adomako, Prince",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": "2018-06-05",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": "2018-12-31",
#         "Position Start Date": "2018-06-05",
#         "Termination Reason Description": "PayCom Conversion",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX001009",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.4462024739
#     },
#     {
#         "Payroll Name": "Adshade, Thomas Michael",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": "2017-02-01",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": "2018-12-31",
#         "Position Start Date": "2017-02-01",
#         "Termination Reason Description": "PayCom Conversion",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000436",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 3.7850115088
#     },
#     {
#         "Payroll Name": "Agee, Ronald",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Armed Officer",
#         "Hire Date": "2018-03-12",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": "2018-12-31",
#         "Position Start Date": "2018-03-12",
#         "Termination Reason Description": "PayCom Conversion",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000825",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.6789197908
#     },
#     {
#         "Payroll Name": "Agnew, Vanika",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": "2018-08-27",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": "2018-12-31",
#         "Position Start Date": "2018-08-27",
#         "Termination Reason Description": "PayCom Conversion",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX001142",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.2189608586
#     },
#     {
#         "Payroll Name": "Ailey, Billy Vaughndarryl",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": "2017-04-06",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": "2018-12-31",
#         "Position Start Date": "2017-04-06",
#         "Termination Reason Description": "PayCom Conversion",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000519",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 3.6097890584
#     },
#     {
#         "Payroll Name": "Ajayi, Denise",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": "2018-06-14",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": "2018-07-12",
#         "Position Start Date": "2018-06-14",
#         "Termination Reason Description": "Import Created Action",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX001025",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.4215618168
#     },
#     {
#         "Payroll Name": "Akinkunmi, Akintunde",
#         "Business Unit Description": "Darryl's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": "2020-01-23",
#         "Hire Reason Description": "New Position",
#         "Rehire Date": 0,
#         "Termination Date": 0,
#         "Position Start Date": "2020-01-23",
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX004257",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 0.811705554
#     },
#     {
#         "Payroll Name": "Akons, Edward",
#         "Business Unit Description": "Darryl's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Armed Security Officer",
#         "Hire Date": "2010-11-04",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": 0,
#         "Position Start Date": "2010-11-04",
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000114",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 10.0300491542
#     },
#     {
#         "Payroll Name": "Alcaraz-Gomez, Johnny",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Armed Officer",
#         "Hire Date": "2018-04-09",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": "2018-12-31",
#         "Position Start Date": "2018-04-09",
#         "Termination Reason Description": "PayCom Conversion",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000880",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.6022599688
#     },
#     {
#         "Payroll Name": "Alde, William",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": "2017-11-20",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": "2018-02-03",
#         "Position Start Date": "2017-11-20",
#         "Termination Reason Description": "Import Created Action",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000695",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.985559079
#     },
#     {
#         "Payroll Name": "Aldridge, Courtney",
#         "Business Unit Description": "Darryl's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": "2020-05-21",
#         "Hire Reason Description": "New Position",
#         "Rehire Date": 0,
#         "Termination Date": "2020-07-28",
#         "Position Start Date": "2020-05-21",
#         "Termination Reason Description": "Abandoned Job",
#         "Voluntary/Involuntary Termination Flag": "Involuntary",
#         "Position ID": "MVX001646",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 0.4859013103
#     },
#     {
#         "Payroll Name": "Alexander, Brenda Lee",
#         "Business Unit Description": "Steve's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Armed Security Officer",
#         "Hire Date": "2017-01-06",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": 0,
#         "Position Start Date": "2017-01-06",
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000422",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 3.8561956293
#     },
#     {
#         "Payroll Name": "Alexander, DeAndre Ramone",
#         "Business Unit Description": "Darryl's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": "2019-12-23",
#         "Hire Reason Description": "New Position",
#         "Rehire Date": 0,
#         "Termination Date": "2020-02-23",
#         "Position Start Date": "2019-12-23",
#         "Termination Reason Description": "Voluntary Resignation",
#         "Voluntary/Involuntary Termination Flag": "Voluntary",
#         "Position ID": "MVX004147",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 0.8965789284
#     },
#     {
#         "Payroll Name": "Alexander, Devante",
#         "Business Unit Description": "Odom's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Corporal",
#         "Hire Date": "2020-01-07",
#         "Hire Reason Description": "New Position",
#         "Rehire Date": 0,
#         "Termination Date": 0,
#         "Position Start Date": "2020-08-23",
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX004155",
#         "count": 1,
#         "Hire Status": "Rehire",
#         "Years of Service": 0.8555111666
#     },
#     {
#         "Payroll Name": "Alexander, Jameya",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": "2018-10-17",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": "2018-12-31",
#         "Position Start Date": "2018-10-17",
#         "Termination Reason Description": "PayCom Conversion",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX001215",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.0793304684
#     },
#     {
#         "Payroll Name": "Alexander, Katina",
#         "Business Unit Description": "Alicia's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Armed Security Officer",
#         "Hire Date": "2018-01-10",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": "2019-10-14",
#         "Position Start Date": "2018-01-10",
#         "Termination Reason Description": "Personal",
#         "Voluntary/Involuntary Termination Flag": "Voluntary",
#         "Position ID": "MVX000727",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.8459286888
#     },
#     {
#         "Payroll Name": "Alexander, Keith",
#         "Business Unit Description": "Darryl's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": "2020-06-25",
#         "Hire Reason Description": "New Position",
#         "Rehire Date": 0,
#         "Termination Date": "2020-08-28",
#         "Position Start Date": "2020-06-25",
#         "Termination Reason Description": "Abandoned Job",
#         "Voluntary/Involuntary Termination Flag": "Involuntary",
#         "Position ID": "MVX001889",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 0.3900765328
#     },
#     {
#         "Payroll Name": "Alexander, Sabrina",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": "2018-04-23",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": "2018-07-12",
#         "Position Start Date": "2018-04-23",
#         "Termination Reason Description": "Import Created Action",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000892",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.5639300577
#     },
#     {
#         "Payroll Name": "Alexander, Sierra",
#         "Business Unit Description": "Steve's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": "2018-10-08",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": "2019-06-01",
#         "Position Start Date": "2018-10-08",
#         "Termination Reason Description": "Voluntary Resignation",
#         "Voluntary/Involuntary Termination Flag": "Voluntary",
#         "Position ID": "MVX001195",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.1039711255
#     },
#     {
#         "Payroll Name": "Ali, Mohamed Abdirashid",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": "2018-06-01",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": "2018-12-31",
#         "Position Start Date": "2018-06-01",
#         "Termination Reason Description": "PayCom Conversion",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX001000",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.457153877
#     },
#     {
#         "Payroll Name": "Allen, Arlisa Mona",
#         "Business Unit Description": "Steve's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": "2016-10-12",
#         "Hire Reason Description": null,
#         "Rehire Date": "2020-09-03",
#         "Termination Date": 0,
#         "Position Start Date": "2020-09-03",
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000364",
#         "count": 1,
#         "Hire Status": "Rehire",
#         "Years of Service": 4.091650797
#     },
#     {
#         "Payroll Name": "Allen, Christie",
#         "Business Unit Description": "Steve's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": "2020-01-24",
#         "Hire Reason Description": "New Position",
#         "Rehire Date": 0,
#         "Termination Date": "2020-01-29",
#         "Position Start Date": "2020-01-24",
#         "Termination Reason Description": "Voluntary Resignation",
#         "Voluntary/Involuntary Termination Flag": "Voluntary",
#         "Position ID": "MVX004201",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 0.8089677032
#     },
#     {
#         "Payroll Name": "Allen, Christopher",
#         "Business Unit Description": "Darryl's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Armed Security Officer",
#         "Hire Date": "2016-03-14",
#         "Hire Reason Description": null,
#         "Rehire Date": "2017-03-07",
#         "Termination Date": "2019-06-24",
#         "Position Start Date": "2016-03-14",
#         "Termination Reason Description": "Voluntary Resignation",
#         "Voluntary/Involuntary Termination Flag": "Voluntary",
#         "Position ID": "MVX000278",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 4.6720751638
#     },
#     {
#         "Payroll Name": "Allen, Cortney",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Armed Officer",
#         "Hire Date": "2018-09-24",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": "2018-12-31",
#         "Position Start Date": "2018-09-24",
#         "Termination Reason Description": "PayCom Conversion",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX001191",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.1423010365
#     },
#     {
#         "Payroll Name": "Allen, Dantrell",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Armed Officer",
#         "Hire Date": "2016-02-12",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": "2018-12-31",
#         "Position Start Date": "2016-02-12",
#         "Termination Reason Description": "PayCom Conversion",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000266",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 4.7569485382
#     },
#     {
#         "Payroll Name": "Allen, Tiffany Danielle",
#         "Business Unit Description": "Odom's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": "2020-10-26",
#         "Hire Reason Description": "New Position",
#         "Rehire Date": 0,
#         "Termination Date": 0,
#         "Position Start Date": "2020-10-26",
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX002131",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 0.0533208859
#     },
#     {
#         "Payroll Name": "Allen, Trevonne",
#         "Business Unit Description": "Odom's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": "2020-09-17",
#         "Hire Reason Description": "New Position",
#         "Rehire Date": 0,
#         "Termination Date": 0,
#         "Position Start Date": "2020-09-17",
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX002052",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 0.1600970666
#     },
#     {
#         "Payroll Name": "Alston, Barron R",
#         "Business Unit Description": "Odom's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Police Officer",
#         "Hire Date": "2012-07-08",
#         "Hire Reason Description": "Existing Position",
#         "Rehire Date": "2019-07-01",
#         "Termination Date": 0,
#         "Position Start Date": "2012-07-08",
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000133",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 8.3544844725
#     },
#     {
#         "Payroll Name": "Alston, Barron R",
#         "Business Unit Description": "Odom's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Police Officer",
#         "Hire Date": "2012-07-08",
#         "Hire Reason Description": "Existing Position",
#         "Rehire Date": 0,
#         "Termination Date": 0,
#         "Position Start Date": "2019-04-01",
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "RJS000133",
#         "count": 1,
#         "Hire Status": "Rehire",
#         "Years of Service": 8.3544844725
#     },
#     {
#         "Payroll Name": "Alvarez, Javier",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Police Officer Sworn Peace Officer",
#         "Hire Date": "2018-04-01",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": "2018-12-31",
#         "Position Start Date": "2018-04-01",
#         "Termination Reason Description": "PayCom Conversion",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000856",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.6241627751
#     },
#     {
#         "Payroll Name": "Amick, Tatanna",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": "2018-05-07",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": "2018-12-31",
#         "Position Start Date": "2018-05-07",
#         "Termination Reason Description": "PayCom Conversion",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000964",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.5256001467
#     },
#     {
#         "Payroll Name": "Anderson, Antoine",
#         "Business Unit Description": "Alicia's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Police Officer",
#         "Hire Date": "2018-10-12",
#         "Hire Reason Description": "New Position",
#         "Rehire Date": 0,
#         "Termination Date": "2019-07-01",
#         "Position Start Date": "2018-10-12",
#         "Termination Reason Description": "Reorganization",
#         "Voluntary/Involuntary Termination Flag": "Voluntary",
#         "Position ID": "MVX001209",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.0930197223
#     },
#     {
#         "Payroll Name": "Anderson, Antoine",
#         "Business Unit Description": "Steve's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Police Officer",
#         "Hire Date": "2018-10-12",
#         "Hire Reason Description": "New Position",
#         "Rehire Date": "2020-03-27",
#         "Termination Date": "2020-07-28",
#         "Position Start Date": "2019-04-01",
#         "Termination Reason Description": "Abandoned Job",
#         "Voluntary/Involuntary Termination Flag": "Involuntary",
#         "Position ID": "RJS001209",
#         "count": 1,
#         "Hire Status": "Rehire",
#         "Years of Service": 2.0930197223
#     },
#     {
#         "Payroll Name": "Anderson, Dante",
#         "Business Unit Description": "Steve's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Armed Security Officer",
#         "Hire Date": "2018-02-07",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": "2019-07-24",
#         "Position Start Date": "2018-02-07",
#         "Termination Reason Description": "Voluntary Resignation",
#         "Voluntary/Involuntary Termination Flag": "Voluntary",
#         "Position ID": "MVX000768",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.7692688668
#     },
#     {
#         "Payroll Name": "Anderson, Dovien",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Armed Officer",
#         "Hire Date": "2011-11-01",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": "2018-12-31",
#         "Position Start Date": "2011-11-01",
#         "Termination Reason Description": "PayCom Conversion",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000123",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 9.0389471693
#     },
#     {
#         "Payroll Name": "Anderson, Jadonna Shontrese",
#         "Business Unit Description": "Steve's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Armed Security Officer",
#         "Hire Date": "2017-04-03",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": 0,
#         "Position Start Date": "2017-04-03",
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000507",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 3.6180026108
#     },
#     {
#         "Payroll Name": "Anderson, John",
#         "Business Unit Description": "Darryl's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": "2020-08-25",
#         "Hire Reason Description": "New Position",
#         "Rehire Date": 0,
#         "Termination Date": 0,
#         "Position Start Date": "2020-08-25",
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX002015",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 0.2230676347
#     },
#     {
#         "Payroll Name": "Anderson, Jonathan",
#         "Business Unit Description": "Alicia's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": "2019-04-29",
#         "Hire Reason Description": "Existing Position",
#         "Rehire Date": 0,
#         "Termination Date": "2019-06-01",
#         "Position Start Date": "2019-04-29",
#         "Termination Reason Description": "Abandoned Job",
#         "Voluntary/Involuntary Termination Flag": "Involuntary",
#         "Position ID": "MVX001578",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 1.5481874157
#     },
#     {
#         "Payroll Name": "Anderson, Kendrick Broshaun",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Armed Officer",
#         "Hire Date": "2017-02-23",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": "2018-12-31",
#         "Position Start Date": "2017-02-23",
#         "Termination Reason Description": "PayCom Conversion",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000452",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 3.7247787915
#     },
#     {
#         "Payroll Name": "Anderson, Kentriss",
#         "Business Unit Description": "Odom's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": "2020-06-25",
#         "Hire Reason Description": "New Position",
#         "Rehire Date": 0,
#         "Termination Date": 0,
#         "Position Start Date": "2020-06-25",
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX001892",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 0.3900765328
#     },
#     {
#         "Payroll Name": "Anderson, Mable",
#         "Business Unit Description": "Darryl's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": "2019-05-30",
#         "Hire Reason Description": "Existing Position",
#         "Rehire Date": 0,
#         "Termination Date": 0,
#         "Position Start Date": "2019-05-30",
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX001682",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 1.4633140413
#     },
#     {
#         "Payroll Name": "Anderson, Odessa",
#         "Business Unit Description": "Steve's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": "2019-05-30",
#         "Hire Reason Description": "Existing Position",
#         "Rehire Date": 0,
#         "Termination Date": "2020-02-23",
#         "Position Start Date": "2019-05-30",
#         "Termination Reason Description": "Voluntary Resignation",
#         "Voluntary/Involuntary Termination Flag": "Voluntary",
#         "Position ID": "MVX001678",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 1.4633140413
#     },
#     {
#         "Payroll Name": "Anderson, Robert",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": "2016-05-05",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": "2018-07-13",
#         "Position Start Date": "2016-05-05",
#         "Termination Reason Description": "Import Created Action",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000299",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 4.5297069229
#     },
#     {
#         "Payroll Name": "Anderson, Shaquana Denise",
#         "Business Unit Description": "Steve's Region",
#         "Position Status": "Leave",
#         "Job Title Description": "Armed Security Officer",
#         "Hire Date": "2016-10-13",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": 0,
#         "Position Start Date": "2016-10-13",
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000368",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 4.0889129462
#     },
#     {
#         "Payroll Name": "Anderson, Taneisha L",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Armed Officer",
#         "Hire Date": "2016-09-29",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": "2018-12-31",
#         "Position Start Date": "2016-09-29",
#         "Termination Reason Description": "PayCom Conversion",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000346",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 4.1272428572
#     },
#     {
#         "Payroll Name": "Andrews, Amanda",
#         "Business Unit Description": "Steve's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Armed Security Officer",
#         "Hire Date": "2019-05-13",
#         "Hire Reason Description": "Existing Position",
#         "Rehire Date": 0,
#         "Termination Date": "2020-07-30",
#         "Position Start Date": "2019-05-13",
#         "Termination Reason Description": "Abandoned Job",
#         "Voluntary/Involuntary Termination Flag": "Involuntary",
#         "Position ID": "MVX001623",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 1.5098575047
#     },
#     {
#         "Payroll Name": "Angry, Tayron Lamont",
#         "Business Unit Description": "Alicia's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Armed Security Officer",
#         "Hire Date": "2016-11-17",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": 0,
#         "Position Start Date": "2020-05-17",
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000393",
#         "count": 1,
#         "Hire Status": "Rehire",
#         "Years of Service": 3.9930881686
#     },
#     {
#         "Payroll Name": "Antunez, Valeria A",
#         "Business Unit Description": "Darryl's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Armed Security Officer",
#         "Hire Date": "2018-03-05",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": "2019-07-18",
#         "Position Start Date": "2018-03-05",
#         "Termination Reason Description": "Voluntary Resignation",
#         "Voluntary/Involuntary Termination Flag": "Voluntary",
#         "Position ID": "MVX000787",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.6980847463
#     },
#     {
#         "Payroll Name": "Appling, Taylor",
#         "Business Unit Description": "Odom's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": "2020-08-21",
#         "Hire Reason Description": "New Position",
#         "Rehire Date": 0,
#         "Termination Date": 0,
#         "Position Start Date": "2020-08-21",
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX002005",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 0.2340190379
#     },
#     {
#         "Payroll Name": "Archer, William Allen",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Armed Officer",
#         "Hire Date": "2016-11-23",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": "2019-02-22",
#         "Position Start Date": "2016-11-23",
#         "Termination Reason Description": "PayCom Conversion",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000397",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 3.9766610639
#     },
#     {
#         "Payroll Name": "Armster, David",
#         "Business Unit Description": "Alicia's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": "2018-11-05",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": "2020-02-05",
#         "Position Start Date": "2018-11-05",
#         "Termination Reason Description": "Abandoned Job",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX001254",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.0273113035
#     },
#     {
#         "Payroll Name": "Armstrong, Kendall",
#         "Business Unit Description": "Steve's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Armed Security Officer",
#         "Hire Date": "2019-01-07",
#         "Hire Reason Description": "New Position",
#         "Rehire Date": 0,
#         "Termination Date": 0,
#         "Position Start Date": "2019-01-07",
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX001394",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 1.8548267039
#     },
#     {
#         "Payroll Name": "Ashford, Deja Desiree",
#         "Business Unit Description": "Steve's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Armed Security Officer",
#         "Hire Date": "2017-05-10",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": "2019-11-25",
#         "Position Start Date": "2017-05-10",
#         "Termination Reason Description": "Personal",
#         "Voluntary/Involuntary Termination Flag": "Voluntary",
#         "Position ID": "MVX000553",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 3.5167021317
#     },
#     {
#         "Payroll Name": "Ashford, Wayne Lamont",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Police Officer Sworn Peace Officer",
#         "Hire Date": "2017-03-13",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
# ...
#         "Business Unit Description": "Darryl's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": "2020-03-02",
#         "Hire Reason Description": "New Position",
#         "Rehire Date": 0,
#         "Termination Date": 0,
#         "Position Start Date": "2020-03-02",
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX004303",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 0.7049293733
#     },
#     {
#         "Payroll Name": "Wright, Precious",
#         "Business Unit Description": "Darryl's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": "2020-11-09",
#         "Hire Reason Description": "New Position",
#         "Rehire Date": 0,
#         "Termination Date": 0,
#         "Position Start Date": "2020-11-09",
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX002182",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 0.0149909749
#     },
#     {
#         "Payroll Name": "Wright, Raniesha",
#         "Business Unit Description": "Odom's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": "2019-09-16",
#         "Hire Reason Description": "New Position",
#         "Rehire Date": 0,
#         "Termination Date": "2020-02-23",
#         "Position Start Date": "2019-09-16",
#         "Termination Reason Description": "Voluntary Resignation",
#         "Voluntary/Involuntary Termination Flag": "Voluntary",
#         "Position ID": "MVX004003",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 1.1648883055
#     },
#     {
#         "Payroll Name": "Wright, Timothy Jermaine",
#         "Business Unit Description": "Alicia's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Armed Security Officer",
#         "Hire Date": "2017-01-27",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": 0,
#         "Position Start Date": "2017-01-27",
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000434",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 3.7987007627
#     },
#     {
#         "Payroll Name": "Wrobel, Adrian",
#         "Business Unit Description": "Alicia's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Armed Security Officer",
#         "Hire Date": "2017-07-13",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": 0,
#         "Position Start Date": "2017-07-13",
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000606",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 3.3414796813
#     },
#     {
#         "Payroll Name": "Yalley, Chrishana",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": "2018-09-06",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": "2018-12-31",
#         "Position Start Date": "2018-09-06",
#         "Termination Reason Description": "PayCom Conversion",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX001156",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.1915823507
#     },
#     {
#         "Payroll Name": "Yarbrough, Alexus",
#         "Business Unit Description": "Darryl's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Non Commission Officer",
#         "Hire Date": "2020-08-09",
#         "Hire Reason Description": "New Position",
#         "Rehire Date": 0,
#         "Termination Date": 0,
#         "Position Start Date": "2020-08-09",
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX001998",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 0.2668732473
#     },
#     {
#         "Payroll Name": "Yates, Passion",
#         "Business Unit Description": "Steve's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": "2019-04-01",
#         "Hire Reason Description": "Existing Position",
#         "Rehire Date": 0,
#         "Termination Date": "2019-08-05",
#         "Position Start Date": "2019-04-01",
#         "Termination Reason Description": "Voluntary Resignation",
#         "Voluntary/Involuntary Termination Flag": "Voluntary",
#         "Position ID": "MVX001557",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 1.6248472377
#     },
#     {
#         "Payroll Name": "Yerow, Abdi Hassan",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": "2018-05-15",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": "2018-07-10",
#         "Position Start Date": "2018-05-15",
#         "Termination Reason Description": "Import Created Action",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000991",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.5036973404
#     },
#     {
#         "Payroll Name": "Young, Debra",
#         "Business Unit Description": "Odom's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": "2020-02-17",
#         "Hire Reason Description": "New Position",
#         "Rehire Date": 0,
#         "Termination Date": "2020-06-02",
#         "Position Start Date": "2020-02-17",
#         "Termination Reason Description": "Abandoned Job",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX004273",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 0.7432592843
#     },
#     {
#         "Payroll Name": "Young, DejAsia",
#         "Business Unit Description": "Odom's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Armed Security Officer",
#         "Hire Date": "2019-10-30",
#         "Hire Reason Description": "New Position",
#         "Rehire Date": "2020-04-17",
#         "Termination Date": 0,
#         "Position Start Date": "2020-04-17",
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": "Voluntary",
#         "Position ID": "MVX004094",
#         "count": 1,
#         "Hire Status": "Rehire",
#         "Years of Service": 1.0444228709
#     },
#     {
#         "Payroll Name": "Young, Devontae",
#         "Business Unit Description": "Darryl's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": "2020-06-05",
#         "Hire Reason Description": "New Position",
#         "Rehire Date": 0,
#         "Termination Date": 0,
#         "Position Start Date": "2020-06-05",
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX001859",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 0.4448335485
#     },
#     {
#         "Payroll Name": "Young, Dominique Latoya",
#         "Business Unit Description": "Steve's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": "2019-11-25",
#         "Hire Reason Description": "New Position",
#         "Rehire Date": 0,
#         "Termination Date": "2020-01-28",
#         "Position Start Date": "2019-11-25",
#         "Termination Reason Description": "Voluntary Resignation",
#         "Voluntary/Involuntary Termination Flag": "Voluntary",
#         "Position ID": "MVX004116",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 0.9732387504
#     },
#     {
#         "Payroll Name": "Young, Erica",
#         "Business Unit Description": "Darryl's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Armed Security Officer",
#         "Hire Date": "2019-02-04",
#         "Hire Reason Description": "New Position",
#         "Rehire Date": 0,
#         "Termination Date": 0,
#         "Position Start Date": "2019-02-04",
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX001453",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 1.7781668818
#     },
#     {
#         "Payroll Name": "Young, Erin",
#         "Business Unit Description": "Administration",
#         "Position Status": "Active",
#         "Job Title Description": "Marketing & Sales Coordinator",
#         "Hire Date": "2019-01-28",
#         "Hire Reason Description": "New Position",
#         "Rehire Date": "2020-07-20",
#         "Termination Date": 0,
#         "Position Start Date": "2020-10-04",
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX001424",
#         "count": 1,
#         "Hire Status": "Rehire",
#         "Years of Service": 1.7973318373
#     },
#     {
#         "Payroll Name": "Young, Javan",
#         "Business Unit Description": "Darryl's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Armed Security Officer",
#         "Hire Date": "2016-03-21",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": 0,
#         "Position Start Date": "2016-03-21",
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000280",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 4.6529102083
#     },
#     {
#         "Payroll Name": "Young, Marshawn",
#         "Business Unit Description": "Alicia's Region",
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": "2019-02-04",
#         "Hire Reason Description": "New Position",
#         "Rehire Date": 0,
#         "Termination Date": "2020-02-25",
#         "Position Start Date": "2019-02-04",
#         "Termination Reason Description": "Abandoned Job",
#         "Voluntary/Involuntary Termination Flag": "Involuntary",
#         "Position ID": "MVX001437",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 1.7781668818
#     },
#     {
#         "Payroll Name": "Young, Raven A",
#         "Business Unit Description": "Odom's Region",
#         "Position Status": "Leave",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": "2020-02-03",
#         "Hire Reason Description": "New Position",
#         "Rehire Date": 0,
#         "Termination Date": 0,
#         "Position Start Date": "2020-02-03",
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX004230",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 0.7815891953
#     },
#     {
#         "Payroll Name": "Youngblood, Desmond",
#         "Business Unit Description": "Darryl's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": "2020-07-01",
#         "Hire Reason Description": "New Position",
#         "Rehire Date": 0,
#         "Termination Date": 0,
#         "Position Start Date": "2020-07-01",
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX001901",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 0.373649428
#     },
#     {
#         "Payroll Name": "Younger, Kameron",
#         "Business Unit Description": "Steve's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Armed Security Officer",
#         "Hire Date": "2015-09-22",
#         "Hire Reason Description": null,
#         "Rehire Date": "2018-06-26",
#         "Termination Date": 0,
#         "Position Start Date": "2015-09-22",
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000209",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 5.1484612008
#     },
#     {
#         "Payroll Name": "Zarif, Alexis",
#         "Business Unit Description": "Steve's Region",
#         "Position Status": "Active",
#         "Job Title Description": "Unarmed Security Officer",
#         "Hire Date": "2018-07-30",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": 0,
#         "Position Start Date": "2018-07-30",
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX001095",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 2.2956206806
#     },
#     {
#         "Payroll Name": "Zayas, Benjamin Joseph",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Armed Officer",
#         "Hire Date": "2016-11-15",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": "2018-04-04",
#         "Position Start Date": "2016-11-15",
#         "Termination Reason Description": "Import Created Action",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000392",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 3.9985638702
#     },
#     {
#         "Payroll Name": "Zayas, Reina",
#         "Business Unit Description": "Administration",
#         "Position Status": "Active",
#         "Job Title Description": "Business Administrator",
#         "Hire Date": "2020-05-22",
#         "Hire Reason Description": "New Position",
#         "Rehire Date": 0,
#         "Termination Date": 0,
#         "Position Start Date": "2020-05-22",
#         "Termination Reason Description": null,
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "RJS004315",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 0.4831634595
#     },
#     {
#         "Payroll Name": "Zayas, Timothy G",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Armed Officer",
#         "Hire Date": "2016-11-18",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": "2018-07-13",
#         "Position Start Date": "2016-11-18",
#         "Termination Reason Description": "Import Created Action",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000395",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 3.9903503178
#     },
#     {
#         "Payroll Name": "Zeigler, Mary R",
#         "Business Unit Description": null,
#         "Position Status": "Terminated",
#         "Job Title Description": "Unarmed Officer",
#         "Hire Date": "2017-03-20",
#         "Hire Reason Description": null,
#         "Rehire Date": 0,
#         "Termination Date": "2018-07-12",
#         "Position Start Date": "2017-03-20",
#         "Termination Reason Description": "Import Created Action",
#         "Voluntary/Involuntary Termination Flag": null,
#         "Position ID": "MVX000486",
#         "count": 1,
#         "Hire Status": "New Hire",
#         "Years of Service": 3.6563325218
#     }
# ]
