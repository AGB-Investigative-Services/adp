# %%
import pandas as pd
import os
import numpy as np
import json

# Reading CSV

data = pd.read_csv('resources/data/Performance Reviews Report.csv', encoding='ISO-8859-1', low_memory=False)

# %%
data
# Out:
#      Employee Last Name, First Name Position ID Position Start Date  \
# 0                    Aaron, Charity   MVX001936           7/20/2020
# 1                    Aaron, Charity   MVX001936           7/20/2020
# 2                      Adams, Amber   MVX001123           8/13/2018
# 3                      Adams, Amber   MVX001123           8/13/2018
# 4                      Adams, Amber   MVX001123           8/13/2018
# ...                             ...         ...                 ...
# 2475               Younger, Kameron   MVX000209           9/22/2015
# 2476                  Zarif, Alexis   MVX001095           7/30/2018
# 2477                  Zarif, Alexis   MVX001095           7/30/2018
# 2478                  Zarif, Alexis   MVX001095           7/30/2018
# 2479                  Zarif, Alexis   MVX001095           7/30/2018
#
#        Reports To Name                 Job Title Business Unit Code  \
# 0           Perry, Roy  Unarmed Security Officer                 DR
# ...
