# %%
# DataFrame handlers
import pandas as pd
import os
import numpy as np

# json
import json

# Datetime Manager
from datetime import datetime as dt
from datetime import timedelta, time, date


# data = pd.read_csv('resources/data/Performance Reviews Report.csv', encoding='ISO-8859-1', low_memory=False)
data = pd.read_csv('resources/data/Performance Reviews Report.csv')

# (https://www.dataquest.io/blog/settingwithcopywarning/) To prevent the warning in this case, the solution is to explicitly tell pandas to make a copy when we create the new dataframe:  .copy()

# Filtered main dataset for '30 Day New Hire Review' on column 'Review Name'
day30 = data.loc[data['Review Name'] == '30 Day New Hire Review',:].copy()
day30.shape

# Less efficient way
# reviewer['Status'] = reviewer['Review Progress'].replace('Not Yet Submitted', 'Not Completed')
# reviewer['Status'] = reviewer['Review Progress'].replace('Error in Distribution', 'Not Completed')
# reviewer['Status'] = reviewer['Review Progress'].replace('Terminated', 'Terminated')
# reviewer['Status'] = reviewer['Review Progress'].replace('Delivered to Employee', 'Completed')
# reviewer['Status'] = reviewer['Review Progress'].replace('Finalized', 'Not Pushed')
# reviewer['Status'] = reviewer['Review Progress'].replace('Employee Acknowledged', 'Completed')
# reviewer['Status']

# Filtered day30 dataframe for 'Reviewer' on column 'Contributor'
reviewer = day30.loc[day30['Contributor Role'] == 'Reviewer',:].copy()
reviewer.reset_index(inplace=True, drop=True)
reviewer.shape

reviewer.loc[reviewer['Review Progress'].isnull(),'Review Progress'] = 'No Status'
reviewer

prog_list = reviewer['Review Progress'].tolist()

prog = []

# for status in reviewer['Review Progress']:
for status in prog_list:
    if status == 'Not Yet Submitted':
        a = 'Not Completed'
        prog.append(a)
    elif status == 'Error in Distribution':
        b = 'Not Completed'
        prog.append(b)
    elif status == 'Terminated':
        c = 'Terminated'
        prog.append(c)
    elif status == 'Delivered to Employee':
        d = 'Completed'
        prog.append(d)
    elif status == 'Finalized':
        e = 'Not Pushed'
        prog.append(e)
    elif status == 'Employee Acknowledged':
        f = 'Completed'
        prog.append(f)
    elif status == 'No Status':
        g = 'Not Completed'
        prog.append(g)
    elif status == 'Not Distributed':
        h = 'Not Completed'
        prog.append(h)
    elif status == 'Pending Approval':
        i = 'Not Completed'
        prog.append(i)

reviewer['Status'] = prog
reviewer.shape

reviewer['Position Start Date'] = pd.to_datetime(reviewer['Position Start Date'])
reviewer['Review Due Date'] = pd.to_datetime(reviewer['Review Due Date'])

reviewer['Target Start Due Date (30 Days)'] = reviewer['Position Start Date'] + timedelta(days=30)
reviewer.shape

data_json = reviewer.to_json('resources/data/Performance Reviews Report.json', orient="records")
data_json = reviewer.to_json(orient="records")
parsed = json.loads(data_json)
print(json.dumps(parsed, indent=4))
# Out:
# [
#     {
#         "Employee Last Name, First Name": "Aaron, Charity",
#         "Position ID": "MVX001936",
#         "Position Start Date": 1595203200000,
#         "Reports To Name": "Perry, Roy",
#         "Job Title": "Unarmed Security Officer",
#         "Business Unit Code": "DR",
#         "Business Unit Description": "Darryl's Region",
#         "Department Code": 800000.0,
#         "Department Description": "Field Administration Operations",
#         "Target Review Completion Date": "9/18/2020",
#         "Review Due Date": 1600387200000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": "Completed",
#         "Review Period Start Date": "7/20/2020",
#         "Review Period End Date": "9/18/2020",
#         "Reviewer": "Perchat Murphy",
#         "Review Progress": "Delivered to Employee",
#         "Notice Date": null,
#         "Contributor Last, First Name": "Murphy, Perchat",
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": null,
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": null,
#         "Final Outcome/Recommendation": null,
#         "Status": "Completed",
#         "Target Start Due Date (30 Days)": 1597795200000
#     },
#     {
#         "Employee Last Name, First Name": "Allen, Tiffany",
#         "Position ID": "MVX002131",
#         "Position Start Date": 1603670400000,
#         "Reports To Name": "Lee, Ariel",
#         "Job Title": "Unarmed Security Officer",
#         "Business Unit Code": "OR",
#         "Business Unit Description": "Odom's Region",
#         "Department Code": 800000.0,
#         "Department Description": "Field Administration Operations",
#         "Target Review Completion Date": "12/25/2020",
#         "Review Due Date": 1608854400000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": null,
#         "Review Period Start Date": "10/26/2020",
#         "Review Period End Date": "12/25/2020",
#         "Reviewer": "Ariel Lee",
#         "Review Progress": "No Status",
#         "Notice Date": null,
#         "Contributor Last, First Name": null,
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": null,
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": null,
#         "Final Outcome/Recommendation": null,
#         "Status": "Not Completed",
#         "Target Start Due Date (30 Days)": 1606262400000
#     },
#     {
#         "Employee Last Name, First Name": "Allen, Trevonne",
#         "Position ID": "MVX002052",
#         "Position Start Date": 1600300800000,
#         "Reports To Name": "Land, Charles",
#         "Job Title": "Unarmed Security Officer",
#         "Business Unit Code": "OR",
#         "Business Unit Description": "Odom's Region",
#         "Department Code": 800000.0,
#         "Department Description": "Field Administration Operations",
#         "Target Review Completion Date": "11/16/2020",
#         "Review Due Date": 1605484800000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": "In Progress",
#         "Review Period Start Date": "9/17/2020",
#         "Review Period End Date": "11/16/2020",
#         "Reviewer": "Charles Land",
#         "Review Progress": "Not Yet Submitted",
#         "Notice Date": null,
#         "Contributor Last, First Name": "Land, Charles",
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": null,
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": null,
#         "Final Outcome/Recommendation": null,
#         "Status": "Not Completed",
#         "Target Start Due Date (30 Days)": 1602892800000
#     },
#     {
#         "Employee Last Name, First Name": "Anderson, John",
#         "Position ID": "MVX002015",
#         "Position Start Date": 1598313600000,
#         "Reports To Name": "Long, Prestin",
#         "Job Title": "Unarmed Security Officer",
#         "Business Unit Code": "DR",
#         "Business Unit Description": "Darryl's Region",
#         "Department Code": 800000.0,
#         "Department Description": "Field Administration Operations",
#         "Target Review Completion Date": "10/24/2020",
#         "Review Due Date": 1603497600000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": "In Progress",
#         "Review Period Start Date": "8/25/2020",
#         "Review Period End Date": "10/24/2020",
#         "Reviewer": "Prestin Long",
#         "Review Progress": "Finalized",
#         "Notice Date": null,
#         "Contributor Last, First Name": "Long, Prestin",
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": "Officer no longer works for the company but, if wanted to come back work, i would recommend to be placed as a no to re-hire. Officer work ethic, professionalism, and over all mental is not geared to AGB and is a bad image of what AGB is to the public.",
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": null,
#         "Final Outcome/Recommendation": null,
#         "Status": "Not Pushed",
#         "Target Start Due Date (30 Days)": 1600905600000
#     },
#     {
#         "Employee Last Name, First Name": "Appling, Taylor",
#         "Position ID": "MVX002005",
#         "Position Start Date": 1597968000000,
#         "Reports To Name": "Land, Charles",
#         "Job Title": "Unarmed Security Officer",
#         "Business Unit Code": "OR",
#         "Business Unit Description": "Odom's Region",
#         "Department Code": 800000.0,
#         "Department Description": "Field Administration Operations",
#         "Target Review Completion Date": "10/20/2020",
#         "Review Due Date": 1603152000000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": "In Progress",
#         "Review Period Start Date": "8/21/2020",
#         "Review Period End Date": "10/20/2020",
#         "Reviewer": "Charles Land",
#         "Review Progress": "Not Yet Submitted",
#         "Notice Date": null,
#         "Contributor Last, First Name": "Land, Charles",
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": null,
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": null,
#         "Final Outcome/Recommendation": null,
#         "Status": "Not Completed",
#         "Target Start Due Date (30 Days)": 1600560000000
#     },
#     {
#         "Employee Last Name, First Name": "Baksh, Saheed",
#         "Position ID": "MVX002085",
#         "Position Start Date": 1601856000000,
#         "Reports To Name": "Murphy, Perchat",
#         "Job Title": "Non Commission Officer",
#         "Business Unit Code": "DR",
#         "Business Unit Description": "Darryl's Region",
#         "Department Code": 800000.0,
#         "Department Description": "Field Administration Operations",
#         "Target Review Completion Date": "12/4/2020",
#         "Review Due Date": 1607040000000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": "In Progress",
#         "Review Period Start Date": "10/5/2020",
#         "Review Period End Date": "12/4/2020",
#         "Reviewer": "Perchat Murphy",
#         "Review Progress": "Not Yet Submitted",
#         "Notice Date": null,
#         "Contributor Last, First Name": "Murphy, Perchat",
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": null,
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": null,
#         "Final Outcome/Recommendation": null,
#         "Status": "Not Completed",
#         "Target Start Due Date (30 Days)": 1604448000000
#     },
#     {
#         "Employee Last Name, First Name": "Ballard, Robert",
#         "Position ID": "MVX002025",
#         "Position Start Date": 1597449600000,
#         "Reports To Name": "White, Bernard",
#         "Job Title": "Unarmed Security Officer",
#         "Business Unit Code": "SR",
#         "Business Unit Description": "Steve's Region",
#         "Department Code": 800000.0,
#         "Department Description": "Field Administration Operations",
#         "Target Review Completion Date": "10/14/2020",
#         "Review Due Date": 1602633600000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": "In Progress",
#         "Review Period Start Date": "8/15/2020",
#         "Review Period End Date": "10/14/2020",
#         "Reviewer": "Bernard White",
#         "Review Progress": "Not Yet Submitted",
#         "Notice Date": null,
#         "Contributor Last, First Name": "White, Bernard",
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": null,
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": null,
#         "Final Outcome/Recommendation": null,
#         "Status": "Not Completed",
#         "Target Start Due Date (30 Days)": 1600041600000
#     },
#     {
#         "Employee Last Name, First Name": "Bangs, Donovan",
#         "Position ID": "MVX002013",
#         "Position Start Date": 1598227200000,
#         "Reports To Name": "Murphy, Perchat",
#         "Job Title": "Non Commission Officer",
#         "Business Unit Code": "DR",
#         "Business Unit Description": "Darryl's Region",
#         "Department Code": 800000.0,
#         "Department Description": "Field Administration Operations",
#         "Target Review Completion Date": "10/23/2020",
#         "Review Due Date": 1603411200000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": "In Progress",
#         "Review Period Start Date": "8/24/2020",
#         "Review Period End Date": "10/23/2020",
#         "Reviewer": "Perchat Murphy",
#         "Review Progress": "Not Yet Submitted",
#         "Notice Date": null,
#         "Contributor Last, First Name": "Murphy, Perchat",
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": null,
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": null,
#         "Final Outcome/Recommendation": null,
#         "Status": "Not Completed",
#         "Target Start Due Date (30 Days)": 1600819200000
#     },
#     {
#         "Employee Last Name, First Name": "Barton, Shaniqua",
#         "Position ID": "MVX002097",
#         "Position Start Date": 1602806400000,
#         "Reports To Name": "Lee, Ariel",
#         "Job Title": "Unarmed Security Officer",
#         "Business Unit Code": "OR",
#         "Business Unit Description": "Odom's Region",
#         "Department Code": 800000.0,
#         "Department Description": "Field Administration Operations",
#         "Target Review Completion Date": "12/15/2020",
#         "Review Due Date": 1607990400000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": null,
#         "Review Period Start Date": "10/16/2020",
#         "Review Period End Date": "12/15/2020",
#         "Reviewer": "Ariel Lee",
#         "Review Progress": "No Status",
#         "Notice Date": null,
#         "Contributor Last, First Name": null,
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": null,
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": null,
#         "Final Outcome/Recommendation": null,
#         "Status": "Not Completed",
#         "Target Start Due Date (30 Days)": 1605398400000
#     },
#     {
#         "Employee Last Name, First Name": "Bays, Tianna",
#         "Position ID": "MVX002051",
#         "Position Start Date": 1600128000000,
#         "Reports To Name": "White, Bernard",
#         "Job Title": "Unarmed Officer",
#         "Business Unit Code": "SR",
#         "Business Unit Description": "Steve's Region",
#         "Department Code": 800000.0,
#         "Department Description": "Field Administration Operations",
#         "Target Review Completion Date": "11/14/2020",
#         "Review Due Date": 1605312000000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": "In Progress",
#         "Review Period Start Date": "9/15/2020",
#         "Review Period End Date": "11/14/2020",
#         "Reviewer": "Bernard White",
#         "Review Progress": "Not Yet Submitted",
#         "Notice Date": null,
#         "Contributor Last, First Name": "White, Bernard",
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": null,
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": null,
#         "Final Outcome/Recommendation": null,
#         "Status": "Not Completed",
#         "Target Start Due Date (30 Days)": 1602720000000
#     },
#     {
#         "Employee Last Name, First Name": "Bellamy, Julia",
#         "Position ID": "MVX002063",
#         "Position Start Date": 1600646400000,
#         "Reports To Name": "Griffin, Denitra",
#         "Job Title": "Executive Administrative Assistant",
#         "Business Unit Code": "ADM",
#         "Business Unit Description": "Administration",
#         "Department Code": 200000.0,
#         "Department Description": "Executive Suite",
#         "Target Review Completion Date": "11/20/2020",
#         "Review Due Date": 1605830400000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": "In Progress",
#         "Review Period Start Date": "9/21/2020",
#         "Review Period End Date": "11/20/2020",
#         "Reviewer": "Denitra Griffin",
#         "Review Progress": "Finalized",
#         "Notice Date": null,
#         "Contributor Last, First Name": "Griffin, Denitra",
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": "We are glad Julia is part of the AGB team. We are looking forward to her growth and development.",
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": null,
#         "Final Outcome/Recommendation": null,
#         "Status": "Not Pushed",
#         "Target Start Due Date (30 Days)": 1603238400000
#     },
#     {
#         "Employee Last Name, First Name": "Bevelle, DeAndre",
#         "Position ID": "MVX002049",
#         "Position Start Date": 1599782400000,
#         "Reports To Name": "Murphy, Perchat",
#         "Job Title": "Unarmed Security Officer",
#         "Business Unit Code": "DR",
#         "Business Unit Description": "Darryl's Region",
#         "Department Code": 800000.0,
#         "Department Description": "Field Administration Operations",
#         "Target Review Completion Date": "11/10/2020",
#         "Review Due Date": 1604966400000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": "In Progress",
#         "Review Period Start Date": "9/11/2020",
#         "Review Period End Date": "11/10/2020",
#         "Reviewer": "Perchat Murphy",
#         "Review Progress": "Not Yet Submitted",
#         "Notice Date": null,
#         "Contributor Last, First Name": "Murphy, Perchat",
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": null,
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": null,
#         "Final Outcome/Recommendation": null,
#         "Status": "Not Completed",
#         "Target Start Due Date (30 Days)": 1602374400000
#     },
#     {
#         "Employee Last Name, First Name": "Bonds, Brandy",
#         "Position ID": "MVX002064",
#         "Position Start Date": 1600646400000,
#         "Reports To Name": "Lewis, Malissa",
#         "Job Title": "Unarmed Officer",
#         "Business Unit Code": "SR",
#         "Business Unit Description": "Steve's Region",
#         "Department Code": 800000.0,
#         "Department Description": "Field Administration Operations",
#         "Target Review Completion Date": "11/20/2020",
#         "Review Due Date": 1605830400000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": "In Progress",
#         "Review Period Start Date": "9/21/2020",
#         "Review Period End Date": "11/20/2020",
#         "Reviewer": "Malissa Lewis",
#         "Review Progress": "Not Yet Submitted",
#         "Notice Date": null,
#         "Contributor Last, First Name": "Lewis, Malissa",
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": null,
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": null,
#         "Final Outcome/Recommendation": null,
#         "Status": "Not Completed",
#         "Target Start Due Date (30 Days)": 1603238400000
#     },
#     {
#         "Employee Last Name, First Name": "Boone, Shanita",
#         "Position ID": "MVX002159",
#         "Position Start Date": 1604275200000,
#         "Reports To Name": "Griffin, Darryl",
#         "Job Title": "Unarmed Security Officer",
#         "Business Unit Code": "DR",
#         "Business Unit Description": "Darryl's Region",
#         "Department Code": 800000.0,
#         "Department Description": "Field Administration Operations",
#         "Target Review Completion Date": "1/1/2021",
#         "Review Due Date": 1609459200000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": null,
#         "Review Period Start Date": "11/2/2020",
#         "Review Period End Date": "1/1/2021",
#         "Reviewer": "Darryl Griffin",
#         "Review Progress": "No Status",
#         "Notice Date": null,
#         "Contributor Last, First Name": null,
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": null,
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": null,
#         "Final Outcome/Recommendation": null,
#         "Status": "Not Completed",
#         "Target Start Due Date (30 Days)": 1606867200000
#     },
#     {
#         "Employee Last Name, First Name": "Braswell, Shenita",
#         "Position ID": "MVX002029",
#         "Position Start Date": 1599091200000,
#         "Reports To Name": "Scott, Stephanie",
#         "Job Title": "Unarmed Officer",
#         "Business Unit Code": "SR",
#         "Business Unit Description": "Steve's Region",
#         "Department Code": 800000.0,
#         "Department Description": "Field Administration Operations",
#         "Target Review Completion Date": "11/2/2020",
#         "Review Due Date": 1604275200000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": "In Progress",
#         "Review Period Start Date": "9/3/2020",
#         "Review Period End Date": "11/2/2020",
#         "Reviewer": "Stephanie Scott",
#         "Review Progress": "Not Yet Submitted",
#         "Notice Date": null,
#         "Contributor Last, First Name": "Scott, Stephanie",
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": null,
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": null,
#         "Final Outcome/Recommendation": null,
#         "Status": "Not Completed",
#         "Target Start Due Date (30 Days)": 1601683200000
#     },
#     {
#         "Employee Last Name, First Name": "Brooks, Jasmine",
#         "Position ID": "MVX002140",
#         "Position Start Date": 1603670400000,
#         "Reports To Name": "Lee, Ariel",
#         "Job Title": "Unarmed Security Officer",
#         "Business Unit Code": "OR",
#         "Business Unit Description": "Odom's Region",
#         "Department Code": 800000.0,
#         "Department Description": "Field Administration Operations",
#         "Target Review Completion Date": "12/25/2020",
#         "Review Due Date": 1608854400000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": null,
#         "Review Period Start Date": "10/26/2020",
#         "Review Period End Date": "12/25/2020",
#         "Reviewer": "Ariel Lee",
#         "Review Progress": "No Status",
#         "Notice Date": null,
#         "Contributor Last, First Name": null,
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": null,
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": null,
#         "Final Outcome/Recommendation": null,
#         "Status": "Not Completed",
#         "Target Start Due Date (30 Days)": 1606262400000
#     },
#     {
#         "Employee Last Name, First Name": "Brooks, Jonathan",
#         "Position ID": "MVX002188",
#         "Position Start Date": 1604880000000,
#         "Reports To Name": "White, Bernard",
#         "Job Title": "Unarmed Security Officer",
#         "Business Unit Code": "SR",
#         "Business Unit Description": "Steve's Region",
#         "Department Code": 800000.0,
#         "Department Description": "Field Administration Operations",
#         "Target Review Completion Date": "1/8/2021",
#         "Review Due Date": 1610064000000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": null,
#         "Review Period Start Date": "11/9/2020",
#         "Review Period End Date": "1/8/2021",
#         "Reviewer": "Bernard White",
#         "Review Progress": "No Status",
#         "Notice Date": null,
#         "Contributor Last, First Name": null,
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": null,
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": null,
#         "Final Outcome/Recommendation": null,
#         "Status": "Not Completed",
#         "Target Start Due Date (30 Days)": 1607472000000
#     },
#     {
#         "Employee Last Name, First Name": "Brooks, Terril",
#         "Position ID": "MVX001983",
#         "Position Start Date": 1596758400000,
#         "Reports To Name": "Lee, Ariel",
#         "Job Title": "Unarmed Security Officer",
#         "Business Unit Code": "OR",
#         "Business Unit Description": "Odom's Region",
#         "Department Code": 800000.0,
#         "Department Description": "Field Administration Operations",
#         "Target Review Completion Date": "10/6/2020",
#         "Review Due Date": 1601942400000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": "Completed",
#         "Review Period Start Date": "8/7/2020",
#         "Review Period End Date": "10/6/2020",
#         "Reviewer": "Ariel Lee",
#         "Review Progress": "Delivered to Employee",
#         "Notice Date": null,
#         "Contributor Last, First Name": "Lee, Ariel",
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": null,
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": null,
#         "Final Outcome/Recommendation": null,
#         "Status": "Completed",
#         "Target Start Due Date (30 Days)": 1599350400000
#     },
#     {
#         "Employee Last Name, First Name": "Brown, Terrell",
#         "Position ID": "MVX002133",
#         "Position Start Date": 1603670400000,
#         "Reports To Name": "Woodrick, Misty",
#         "Job Title": "Unarmed Security Officer",
#         "Business Unit Code": "DR",
#         "Business Unit Description": "Darryl's Region",
#         "Department Code": 800000.0,
#         "Department Description": "Field Administration Operations",
#         "Target Review Completion Date": "12/25/2020",
#         "Review Due Date": 1608854400000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": null,
#         "Review Period Start Date": "10/26/2020",
#         "Review Period End Date": "12/25/2020",
#         "Reviewer": "Misty Woodrick",
#         "Review Progress": "No Status",
#         "Notice Date": null,
#         "Contributor Last, First Name": null,
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": null,
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": null,
#         "Final Outcome/Recommendation": null,
#         "Status": "Not Completed",
#         "Target Start Due Date (30 Days)": 1606262400000
#     },
#     {
#         "Employee Last Name, First Name": "Brunt, Inell",
#         "Position ID": "MVX002081",
#         "Position Start Date": 1602460800000,
#         "Reports To Name": "Tassin, Kenya",
#         "Job Title": "Unarmed Security Officer",
#         "Business Unit Code": "DR",
#         "Business Unit Description": "Darryl's Region",
#         "Department Code": 800000.0,
#         "Department Description": "Field Administration Operations",
#         "Target Review Completion Date": "12/11/2020",
#         "Review Due Date": 1607644800000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": "In Progress",
#         "Review Period Start Date": "10/12/2020",
#         "Review Period End Date": "12/11/2020",
#         "Reviewer": "Kenya Tassin",
#         "Review Progress": "Not Yet Submitted",
#         "Notice Date": null,
#         "Contributor Last, First Name": "Tassin, Kenya",
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": null,
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": null,
#         "Final Outcome/Recommendation": null,
#         "Status": "Not Completed",
#         "Target Start Due Date (30 Days)": 1605052800000
#     },
#     {
#         "Employee Last Name, First Name": "Bueno, Joseline",
#         "Position ID": "MVX002069",
#         "Position Start Date": 1600992000000,
#         "Reports To Name": "Perry, Roy",
#         "Job Title": "Unarmed Security Officer",
#         "Business Unit Code": "DR",
#         "Business Unit Description": "Darryl's Region",
#         "Department Code": 800000.0,
#         "Department Description": "Field Administration Operations",
#         "Target Review Completion Date": "11/24/2020",
#         "Review Due Date": 1606176000000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": "In Progress",
#         "Review Period Start Date": "9/25/2020",
#         "Review Period End Date": "11/24/2020",
#         "Reviewer": "Roy Perry",
#         "Review Progress": "Not Yet Submitted",
#         "Notice Date": null,
#         "Contributor Last, First Name": "Perry, Roy",
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": null,
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": null,
#         "Final Outcome/Recommendation": null,
#         "Status": "Not Completed",
#         "Target Start Due Date (30 Days)": 1603584000000
#     },
#     {
#         "Employee Last Name, First Name": "Buie, Jackkie",
#         "Position ID": "MVX002075",
#         "Position Start Date": 1601510400000,
#         "Reports To Name": "Scott, Stephanie",
#         "Job Title": "Unarmed Security Officer",
#         "Business Unit Code": "SR",
#         "Business Unit Description": "Steve's Region",
#         "Department Code": 800000.0,
#         "Department Description": "Field Administration Operations",
#         "Target Review Completion Date": "11/30/2020",
#         "Review Due Date": 1606694400000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": "In Progress",
#         "Review Period Start Date": "10/1/2020",
#         "Review Period End Date": "11/30/2020",
#         "Reviewer": "Stephanie Scott",
#         "Review Progress": "Not Yet Submitted",
#         "Notice Date": null,
#         "Contributor Last, First Name": "Scott, Stephanie",
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": null,
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": null,
#         "Final Outcome/Recommendation": null,
#         "Status": "Not Completed",
#         "Target Start Due Date (30 Days)": 1604102400000
#     },
#     {
#         "Employee Last Name, First Name": "Bulliner, Kaitlyn",
#         "Position ID": "MVX002165",
#         "Position Start Date": 1604361600000,
#         "Reports To Name": "Long, Prestin",
#         "Job Title": "Unarmed Security Officer",
#         "Business Unit Code": "DR",
#         "Business Unit Description": "Darryl's Region",
#         "Department Code": 800000.0,
#         "Department Description": "Field Administration Operations",
#         "Target Review Completion Date": "1/2/2021",
#         "Review Due Date": 1609545600000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": null,
#         "Review Period Start Date": "11/3/2020",
#         "Review Period End Date": "1/2/2021",
#         "Reviewer": "Prestin Long",
#         "Review Progress": "No Status",
#         "Notice Date": null,
#         "Contributor Last, First Name": null,
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": null,
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": null,
#         "Final Outcome/Recommendation": null,
#         "Status": "Not Completed",
#         "Target Start Due Date (30 Days)": 1606953600000
#     },
#     {
#         "Employee Last Name, First Name": "Burks, Jemari",
#         "Position ID": "MVX002116",
#         "Position Start Date": 1603324800000,
#         "Reports To Name": "Scott, Stephanie",
#         "Job Title": "Unarmed Officer",
#         "Business Unit Code": "SR",
#         "Business Unit Description": "Steve's Region",
#         "Department Code": 800000.0,
#         "Department Description": "Field Administration Operations",
#         "Target Review Completion Date": "12/21/2020",
#         "Review Due Date": 1608508800000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": null,
#         "Review Period Start Date": "10/22/2020",
#         "Review Period End Date": "12/21/2020",
#         "Reviewer": "Stephanie Scott",
#         "Review Progress": "No Status",
#         "Notice Date": null,
#         "Contributor Last, First Name": null,
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": null,
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": null,
#         "Final Outcome/Recommendation": null,
#         "Status": "Not Completed",
#         "Target Start Due Date (30 Days)": 1605916800000
#     },
#     {
#         "Employee Last Name, First Name": "Burt, Maurice",
#         "Position ID": "MVX002072",
#         "Position Start Date": 1601251200000,
#         "Reports To Name": "Land, Charles",
#         "Job Title": "Unarmed Security Officer",
#         "Business Unit Code": "OR",
#         "Business Unit Description": "Odom's Region",
#         "Department Code": 800000.0,
#         "Department Description": "Field Administration Operations",
#         "Target Review Completion Date": "11/27/2020",
#         "Review Due Date": 1606435200000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": "In Progress",
#         "Review Period Start Date": "9/28/2020",
#         "Review Period End Date": "11/27/2020",
#         "Reviewer": "Charles Land",
#         "Review Progress": "Not Yet Submitted",
#         "Notice Date": null,
#         "Contributor Last, First Name": "Land, Charles",
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": null,
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": null,
#         "Final Outcome/Recommendation": null,
#         "Status": "Not Completed",
#         "Target Start Due Date (30 Days)": 1603843200000
#     },
#     {
#         "Employee Last Name, First Name": "Butler, Emani",
#         "Position ID": "MVX002145",
#         "Position Start Date": 1603929600000,
#         "Reports To Name": "Lee, Ariel",
#         "Job Title": "Unarmed Protection Specialist",
#         "Business Unit Code": "OR",
#         "Business Unit Description": "Odom's Region",
#         "Department Code": 800000.0,
#         "Department Description": "Field Administration Operations",
#         "Target Review Completion Date": "12/28/2020",
#         "Review Due Date": 1609113600000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": null,
#         "Review Period Start Date": "10/29/2020",
#         "Review Period End Date": "12/28/2020",
#         "Reviewer": "Ariel Lee",
#         "Review Progress": "No Status",
#         "Notice Date": null,
#         "Contributor Last, First Name": null,
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": null,
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": null,
#         "Final Outcome/Recommendation": null,
#         "Status": "Not Completed",
#         "Target Start Due Date (30 Days)": 1606521600000
#     },
#     {
#         "Employee Last Name, First Name": "Byles, Oscar",
#         "Position ID": "MVX002016",
#         "Position Start Date": 1598400000000,
#         "Reports To Name": "White, Bernard",
#         "Job Title": "Unarmed Security Officer",
#         "Business Unit Code": "SR",
#         "Business Unit Description": "Steve's Region",
#         "Department Code": 800000.0,
#         "Department Description": "Field Administration Operations",
#         "Target Review Completion Date": "10/25/2020",
#         "Review Due Date": 1603584000000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": "In Progress",
#         "Review Period Start Date": "8/26/2020",
#         "Review Period End Date": "10/25/2020",
#         "Reviewer": "Bernard White",
#         "Review Progress": "Not Yet Submitted",
#         "Notice Date": null,
#         "Contributor Last, First Name": "White, Bernard",
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": null,
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": null,
#         "Final Outcome/Recommendation": null,
#         "Status": "Not Completed",
#         "Target Start Due Date (30 Days)": 1600992000000
#     },
#     {
#         "Employee Last Name, First Name": "Camargo, Saul",
#         "Position ID": "MVX002071",
#         "Position Start Date": 1601078400000,
#         "Reports To Name": "Land, Charles",
#         "Job Title": "Unarmed Security Officer",
#         "Business Unit Code": "OR",
#         "Business Unit Description": "Odom's Region",
#         "Department Code": 800000.0,
#         "Department Description": "Field Administration Operations",
#         "Target Review Completion Date": "11/25/2020",
#         "Review Due Date": 1606262400000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": "In Progress",
#         "Review Period Start Date": "9/26/2020",
#         "Review Period End Date": "11/25/2020",
#         "Reviewer": "Charles Land",
#         "Review Progress": "Not Yet Submitted",
#         "Notice Date": null,
#         "Contributor Last, First Name": "Land, Charles",
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": null,
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": null,
#         "Final Outcome/Recommendation": null,
#         "Status": "Not Completed",
#         "Target Start Due Date (30 Days)": 1603670400000
#     },
#     {
#         "Employee Last Name, First Name": "Campbell, Tera",
#         "Position ID": "MVX002139",
#         "Position Start Date": 1603670400000,
#         "Reports To Name": "Lee, Ariel",
#         "Job Title": "Unarmed Officer",
#         "Business Unit Code": "OR",
#         "Business Unit Description": "Odom's Region",
#         "Department Code": 800000.0,
#         "Department Description": "Field Administration Operations",
#         "Target Review Completion Date": "12/25/2020",
#         "Review Due Date": 1608854400000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": null,
#         "Review Period Start Date": "10/26/2020",
#         "Review Period End Date": "12/25/2020",
#         "Reviewer": "Ariel Lee",
#         "Review Progress": "No Status",
#         "Notice Date": null,
#         "Contributor Last, First Name": null,
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": null,
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": null,
#         "Final Outcome/Recommendation": null,
#         "Status": "Not Completed",
#         "Target Start Due Date (30 Days)": 1606262400000
#     },
#     {
#         "Employee Last Name, First Name": "Carr, Patricia",
#         "Position ID": "MVX002037",
#         "Position Start Date": 1599177600000,
#         "Reports To Name": "Murphy, Perchat",
#         "Job Title": "Unarmed Security Officer",
#         "Business Unit Code": "DR",
#         "Business Unit Description": "Darryl's Region",
#         "Department Code": 800000.0,
#         "Department Description": "Field Administration Operations",
#         "Target Review Completion Date": "11/3/2020",
#         "Review Due Date": 1604361600000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": "In Progress",
#         "Review Period Start Date": "9/4/2020",
#         "Review Period End Date": "11/3/2020",
#         "Reviewer": "Perchat Murphy",
#         "Review Progress": "Not Yet Submitted",
#         "Notice Date": null,
#         "Contributor Last, First Name": "Murphy, Perchat",
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": null,
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": null,
#         "Final Outcome/Recommendation": null,
#         "Status": "Not Completed",
#         "Target Start Due Date (30 Days)": 1601769600000
#     },
#     {
#         "Employee Last Name, First Name": "Carter, Chiquita",
#         "Position ID": "MVX002167",
#         "Position Start Date": 1604620800000,
#         "Reports To Name": "Dukes, Christopher",
#         "Job Title": "Unarmed Security Officer",
#         "Business Unit Code": "DR",
#         "Business Unit Description": "Darryl's Region",
#         "Department Code": 800000.0,
#         "Department Description": "Field Administration Operations",
#         "Target Review Completion Date": "1/5/2021",
#         "Review Due Date": 1609804800000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": null,
#         "Review Period Start Date": "11/6/2020",
#         "Review Period End Date": "1/5/2021",
#         "Reviewer": "Christopher Dukes",
#         "Review Progress": "No Status",
#         "Notice Date": null,
#         "Contributor Last, First Name": null,
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": null,
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": null,
#         "Final Outcome/Recommendation": null,
#         "Status": "Not Completed",
#         "Target Start Due Date (30 Days)": 1607212800000
#     },
#     {
#         "Employee Last Name, First Name": "Castillo, Martin",
#         "Position ID": "MVX002007",
#         "Position Start Date": 1597968000000,
#         "Reports To Name": null,
#         "Job Title": "Unarmed Security Officer",
#         "Business Unit Code": "DR",
#         "Business Unit Description": "Darryl's Region",
#         "Department Code": 800000.0,
#         "Department Description": "Field Administration Operations",
#         "Target Review Completion Date": "10/20/2020",
#         "Review Due Date": 1603152000000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": "Terminated",
#         "Review Period Start Date": "8/21/2020",
#         "Review Period End Date": "10/20/2020",
#         "Reviewer": "Korsica Hodo",
#         "Review Progress": "Terminated",
#         "Notice Date": null,
#         "Contributor Last, First Name": "Hodo, Korsica",
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": null,
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": null,
#         "Final Outcome/Recommendation": null,
#         "Status": "Terminated",
#         "Target Start Due Date (30 Days)": 1600560000000
#     },
#     {
#         "Employee Last Name, First Name": "Cathery, Avion",
#         "Position ID": "MVX002055",
#         "Position Start Date": 1600300800000,
#         "Reports To Name": "Woodrick, Misty",
#         "Job Title": "Unarmed Officer",
#         "Business Unit Code": "DR",
#         "Business Unit Description": "Darryl's Region",
#         "Department Code": 800000.0,
#         "Department Description": "Field Administration Operations",
#         "Target Review Completion Date": "11/16/2020",
#         "Review Due Date": 1605484800000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": "In Progress",
#         "Review Period Start Date": "9/17/2020",
#         "Review Period End Date": "11/16/2020",
#         "Reviewer": "Misty Woodrick",
#         "Review Progress": "Not Yet Submitted",
#         "Notice Date": null,
#         "Contributor Last, First Name": "Woodrick, Misty",
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": null,
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": null,
#         "Final Outcome/Recommendation": null,
#         "Status": "Not Completed",
#         "Target Start Due Date (30 Days)": 1602892800000
#     },
#     {
#         "Employee Last Name, First Name": "Cavin, Raquel",
#         "Position ID": "MVX002068",
#         "Position Start Date": 1600732800000,
#         "Reports To Name": "Land, Charles",
#         "Job Title": "Unarmed Officer",
#         "Business Unit Code": "OR",
#         "Business Unit Description": "Odom's Region",
#         "Department Code": 800000.0,
#         "Department Description": "Field Administration Operations",
#         "Target Review Completion Date": "11/21/2020",
#         "Review Due Date": 1605916800000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": "In Progress",
#         "Review Period Start Date": "9/22/2020",
#         "Review Period End Date": "11/21/2020",
#         "Reviewer": "Charles Land",
#         "Review Progress": "Not Yet Submitted",
#         "Notice Date": null,
#         "Contributor Last, First Name": "Land, Charles",
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": null,
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": null,
#         "Final Outcome/Recommendation": null,
#         "Status": "Not Completed",
#         "Target Start Due Date (30 Days)": 1603324800000
#     },
#     {
#         "Employee Last Name, First Name": "Coleman, TonyaMarrie",
#         "Position ID": "MVX001972",
#         "Position Start Date": 1596499200000,
#         "Reports To Name": "Samuels, Alicia",
#         "Job Title": "Unarmed Officer",
#         "Business Unit Code": "DR",
#         "Business Unit Description": "Darryl's Region",
#         "Department Code": 800000.0,
#         "Department Description": "Field Administration Operations",
#         "Target Review Completion Date": "10/3/2020",
#         "Review Due Date": 1601683200000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": "In Progress",
#         "Review Period Start Date": "8/4/2020",
#         "Review Period End Date": "10/3/2020",
#         "Reviewer": "Perchat Murphy",
#         "Review Progress": "Not Yet Submitted",
#         "Notice Date": null,
#         "Contributor Last, First Name": "Murphy, Perchat",
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": "Ofc. Tonya Coleman has perform below expectations since her date of hire. She have left work without proper authorization and have been unreliable. Ofc. T. Coleman performance will be monitor over next 15 days and if her performance does not approve she will not be able to work for AGB.",
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": null,
#         "Final Outcome/Recommendation": null,
#         "Status": "Not Completed",
#         "Target Start Due Date (30 Days)": 1599091200000
#     },
#     {
#         "Employee Last Name, First Name": "Cook, Davonti",
#         "Position ID": "MVX002143",
#         "Position Start Date": 1603929600000,
#         "Reports To Name": "Lee, Ariel",
#         "Job Title": "Unarmed Protection Specialist",
#         "Business Unit Code": "OR",
#         "Business Unit Description": "Odom's Region",
#         "Department Code": 800000.0,
#         "Department Description": "Field Administration Operations",
#         "Target Review Completion Date": "12/28/2020",
#         "Review Due Date": 1609113600000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": null,
#         "Review Period Start Date": "10/29/2020",
#         "Review Period End Date": "12/28/2020",
#         "Reviewer": "Ariel Lee",
#         "Review Progress": "No Status",
#         "Notice Date": null,
# ...
#         "Target Review Completion Date": "11/16/2020",
#         "Review Due Date": 1605484800000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": "In Progress",
#         "Review Period Start Date": "9/17/2020",
#         "Review Period End Date": "11/16/2020",
#         "Reviewer": "Stephon Griffin",
#         "Review Progress": "Not Yet Submitted",
#         "Notice Date": null,
#         "Contributor Last, First Name": "Griffin, Stephon",
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": null,
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": null,
#         "Final Outcome/Recommendation": null,
#         "Status": "Not Completed",
#         "Target Start Due Date (30 Days)": 1602892800000
#     },
#     {
#         "Employee Last Name, First Name": "Watson, Kimari",
#         "Position ID": "MVX002024",
#         "Position Start Date": 1598572800000,
#         "Reports To Name": "Samuels, Alicia",
#         "Job Title": "Unarmed Security Officer",
#         "Business Unit Code": "DR",
#         "Business Unit Description": "Darryl's Region",
#         "Department Code": 800000.0,
#         "Department Description": "Field Administration Operations",
#         "Target Review Completion Date": "10/27/2020",
#         "Review Due Date": 1603756800000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": "In Progress",
#         "Review Period Start Date": "8/28/2020",
#         "Review Period End Date": "10/27/2020",
#         "Reviewer": "Prestin Long",
#         "Review Progress": "Not Yet Submitted",
#         "Notice Date": null,
#         "Contributor Last, First Name": "Long, Prestin",
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": null,
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": null,
#         "Final Outcome/Recommendation": null,
#         "Status": "Not Completed",
#         "Target Start Due Date (30 Days)": 1601164800000
#     },
#     {
#         "Employee Last Name, First Name": "Weathers, Jhanae",
#         "Position ID": "MVX002180",
#         "Position Start Date": 1604880000000,
#         "Reports To Name": "Woodrick, Misty",
#         "Job Title": "Unarmed Security Officer",
#         "Business Unit Code": "DR",
#         "Business Unit Description": "Darryl's Region",
#         "Department Code": 800000.0,
#         "Department Description": "Field Administration Operations",
#         "Target Review Completion Date": "1/8/2021",
#         "Review Due Date": 1610064000000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": null,
#         "Review Period Start Date": "11/9/2020",
#         "Review Period End Date": "1/8/2021",
#         "Reviewer": "Misty Woodrick",
#         "Review Progress": "No Status",
#         "Notice Date": null,
#         "Contributor Last, First Name": null,
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": null,
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": null,
#         "Final Outcome/Recommendation": null,
#         "Status": "Not Completed",
#         "Target Start Due Date (30 Days)": 1607472000000
#     },
#     {
#         "Employee Last Name, First Name": "Williamson, Christina",
#         "Position ID": "MVX002086",
#         "Position Start Date": 1601856000000,
#         "Reports To Name": "Lee, Ariel",
#         "Job Title": "Unarmed Security Officer",
#         "Business Unit Code": "OR",
#         "Business Unit Description": "Odom's Region",
#         "Department Code": 800000.0,
#         "Department Description": "Field Administration Operations",
#         "Target Review Completion Date": "12/4/2020",
#         "Review Due Date": 1607040000000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": "In Progress",
#         "Review Period Start Date": "10/5/2020",
#         "Review Period End Date": "12/4/2020",
#         "Reviewer": "Ariel Lee",
#         "Review Progress": "Not Yet Submitted",
#         "Notice Date": null,
#         "Contributor Last, First Name": "Lee, Ariel",
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": null,
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": null,
#         "Final Outcome/Recommendation": null,
#         "Status": "Not Completed",
#         "Target Start Due Date (30 Days)": 1604448000000
#     },
#     {
#         "Employee Last Name, First Name": "Wilson, Brandon",
#         "Position ID": "MVX002048",
#         "Position Start Date": 1599782400000,
#         "Reports To Name": "Murphy, Perchat",
#         "Job Title": "Unarmed Security Officer",
#         "Business Unit Code": "DR",
#         "Business Unit Description": "Darryl's Region",
#         "Department Code": 800000.0,
#         "Department Description": "Field Administration Operations",
#         "Target Review Completion Date": "11/10/2020",
#         "Review Due Date": 1604966400000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": "In Progress",
#         "Review Period Start Date": "9/11/2020",
#         "Review Period End Date": "11/10/2020",
#         "Reviewer": "Perchat Murphy",
#         "Review Progress": "Not Yet Submitted",
#         "Notice Date": null,
#         "Contributor Last, First Name": "Murphy, Perchat",
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": null,
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": null,
#         "Final Outcome/Recommendation": null,
#         "Status": "Not Completed",
#         "Target Start Due Date (30 Days)": 1602374400000
#     },
#     {
#         "Employee Last Name, First Name": "Wilson, Floyd",
#         "Position ID": "MVX002089",
#         "Position Start Date": 1602806400000,
#         "Reports To Name": "Scott, Stephanie",
#         "Job Title": "Unarmed Security Officer",
#         "Business Unit Code": "SR",
#         "Business Unit Description": "Steve's Region",
#         "Department Code": 800000.0,
#         "Department Description": "Field Administration Operations",
#         "Target Review Completion Date": "12/15/2020",
#         "Review Due Date": 1607990400000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": null,
#         "Review Period Start Date": "10/16/2020",
#         "Review Period End Date": "12/15/2020",
#         "Reviewer": "Stephanie Scott",
#         "Review Progress": "No Status",
#         "Notice Date": null,
#         "Contributor Last, First Name": null,
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": null,
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": null,
#         "Final Outcome/Recommendation": null,
#         "Status": "Not Completed",
#         "Target Start Due Date (30 Days)": 1605398400000
#     },
#     {
#         "Employee Last Name, First Name": "Wilson, Menyata",
#         "Position ID": "MVX002122",
#         "Position Start Date": 1603670400000,
#         "Reports To Name": "Lee, Ariel",
#         "Job Title": "Unarmed ComEd Dispatcher",
#         "Business Unit Code": "OR",
#         "Business Unit Description": "Odom's Region",
#         "Department Code": 800000.0,
#         "Department Description": "Field Administration Operations",
#         "Target Review Completion Date": "12/25/2020",
#         "Review Due Date": 1608854400000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": null,
#         "Review Period Start Date": "10/26/2020",
#         "Review Period End Date": "12/25/2020",
#         "Reviewer": "Ariel Lee",
#         "Review Progress": "No Status",
#         "Notice Date": null,
#         "Contributor Last, First Name": null,
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": null,
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": null,
#         "Final Outcome/Recommendation": null,
#         "Status": "Not Completed",
#         "Target Start Due Date (30 Days)": 1606262400000
#     },
#     {
#         "Employee Last Name, First Name": "Woodrick, Misty",
#         "Position ID": "MVX000253",
#         "Position Start Date": 1597104000000,
#         "Reports To Name": "Tassin, Kenya",
#         "Job Title": "Captain",
#         "Business Unit Code": "DR",
#         "Business Unit Description": "Darryl's Region",
#         "Department Code": 800000.0,
#         "Department Description": "Field Administration Operations",
#         "Target Review Completion Date": "10/10/2020",
#         "Review Due Date": 1602288000000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": "Completed",
#         "Review Period Start Date": "8/11/2020",
#         "Review Period End Date": "10/10/2020",
#         "Reviewer": "Kenya Tassin",
#         "Review Progress": "Employee Acknowledged",
#         "Notice Date": null,
#         "Contributor Last, First Name": "Tassin, Kenya",
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": "Overall I believe Misty is an asset to our region. She knows the business very well and has the respect of her peers and subordinates. I would like to see her fine tune her approach to upper leadership and continue to learn. She has currently been tasked with hold her subordinates accountable appropriately i.e documenting.",
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": "10/28/2020",
#         "Final Outcome/Recommendation": null,
#         "Status": "Completed",
#         "Target Start Due Date (30 Days)": 1599696000000
#     },
#     {
#         "Employee Last Name, First Name": "Woods, KaShena",
#         "Position ID": "MVX002121",
#         "Position Start Date": 1603756800000,
#         "Reports To Name": "Lee, Ariel",
#         "Job Title": "Unarmed Officer",
#         "Business Unit Code": "OR",
#         "Business Unit Description": "Odom's Region",
#         "Department Code": 800000.0,
#         "Department Description": "Field Administration Operations",
#         "Target Review Completion Date": "12/26/2020",
#         "Review Due Date": 1608940800000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": null,
#         "Review Period Start Date": "10/27/2020",
#         "Review Period End Date": "12/26/2020",
#         "Reviewer": "Ariel Lee",
#         "Review Progress": "No Status",
#         "Notice Date": null,
#         "Contributor Last, First Name": null,
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": null,
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": null,
#         "Final Outcome/Recommendation": null,
#         "Status": "Not Completed",
#         "Target Start Due Date (30 Days)": 1606348800000
#     },
#     {
#         "Employee Last Name, First Name": "Wright, Precious",
#         "Position ID": "MVX002182",
#         "Position Start Date": 1604880000000,
#         "Reports To Name": "Woodrick, Misty",
#         "Job Title": "Unarmed Security Officer",
#         "Business Unit Code": "DR",
#         "Business Unit Description": "Darryl's Region",
#         "Department Code": 800000.0,
#         "Department Description": "Field Administration Operations",
#         "Target Review Completion Date": "1/8/2021",
#         "Review Due Date": 1610064000000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": null,
#         "Review Period Start Date": "11/9/2020",
#         "Review Period End Date": "1/8/2021",
#         "Reviewer": "Misty Woodrick",
#         "Review Progress": "No Status",
#         "Notice Date": null,
#         "Contributor Last, First Name": null,
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": null,
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": null,
#         "Final Outcome/Recommendation": null,
#         "Status": "Not Completed",
#         "Target Start Due Date (30 Days)": 1607472000000
#     },
#     {
#         "Employee Last Name, First Name": "Yarbrough, Alexus",
#         "Position ID": "MVX001998",
#         "Position Start Date": 1596931200000,
#         "Reports To Name": "Murphy, Perchat",
#         "Job Title": "Non Commission Officer",
#         "Business Unit Code": "DR",
#         "Business Unit Description": "Darryl's Region",
#         "Department Code": 800000.0,
#         "Department Description": "Field Administration Operations",
#         "Target Review Completion Date": "10/8/2020",
#         "Review Due Date": 1602115200000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": "In Progress",
#         "Review Period Start Date": "8/9/2020",
#         "Review Period End Date": "10/8/2020",
#         "Reviewer": "Perchat Murphy",
#         "Review Progress": "Not Yet Submitted",
#         "Notice Date": null,
#         "Contributor Last, First Name": "Murphy, Perchat",
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": null,
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": null,
#         "Final Outcome/Recommendation": null,
#         "Status": "Not Completed",
#         "Target Start Due Date (30 Days)": 1599523200000
#     },
#     {
#         "Employee Last Name, First Name": "Young, Erin",
#         "Position ID": "MVX001424",
#         "Position Start Date": 1601769600000,
#         "Reports To Name": "Coley, Venetta",
#         "Job Title": "Fingerprint Specialist",
#         "Business Unit Code": "ADM",
#         "Business Unit Description": "Administration",
#         "Department Code": 600000.0,
#         "Department Description": "Marketing & Sales",
#         "Target Review Completion Date": "9/18/2020",
#         "Review Due Date": 1600387200000,
#         "Review Detail Name": "30 Day New Hire Review",
#         "Review Name": "30 Day New Hire Review",
#         "Review Detail Status": "Completed",
#         "Review Period Start Date": "7/20/2020",
#         "Review Period End Date": "9/18/2020",
#         "Reviewer": "Venetta Coley",
#         "Review Progress": "Employee Acknowledged",
#         "Notice Date": null,
#         "Contributor Last, First Name": "Coley, Venetta",
#         "Contributor Role": "Reviewer",
#         "Overall Score": null,
#         "Overall Rating Name": null,
#         "Overall Comments": "Erin has adapted well to this new position and is committed to reaching the departments KPI's. She has a good attitude and understands the importance of increasing the business.",
#         "Employee Acknowledgement Comments": null,
#         "Employee Acknowledgement Date": "9/14/2020",
#         "Final Outcome/Recommendation": null,
#         "Status": "Completed",
#         "Target Start Due Date (30 Days)": 1604361600000
#     }
# ]

# %%
reviewer[['Contributor Role','Position Start Date', 'Target Start Due Date (30 Days)','Target Review Completion Date','Review Due Date','Review Period Start Date', 'Review Period End Date']].head(3)

# %%
reviewer[[ 'Review Due Date', 'Target Start Due Date (30 Days)', 'Status']].head(3)

# %%
a < b & b > a

# %%
reviewer['Goal Status'] = ''

reviewer.loc[((reviewer['Target Start Due Date (30 Days)'] < reviewer['Review Due Date']) & (reviewer['Review Due Date'] > reviewer['Target Start Due Date (30 Days)']) & (reviewer['Status'] == 'Completed')), 'Goal Status' ] = 'Met'
# reviewer.loc[((reviewer['Target Due Date'] > reviewer['Review Due Date']) & (reviewer['Status'] == 'Completed')), 'Goal Status' ] = 'Met'
reviewer

# %%
reviewer.loc[reviewer['Status'] == 'Completed'].head(50)

# %%
data['Review Name'].value_counts() # Create two more datatable for 90 Day..., and 180 Day...,
# An Additional dataframe for Manager, Admin...  and Post positional

# %% [markdown]
# # Add Timestamp column with API data of column "Review Detail Status"
